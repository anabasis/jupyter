# %%
from sklearn import datasets
data = datasets.load_boston()

# %%
#len(data.data), data
X = data.data[:,0]
Y = data.target
len(X), len(Y)
# Out:
# (506, 506)

# %%
import matplotlib.pyplot as plt
plt.scatter(X,Y)
plt.show()

# %%
import numpy as np
X = np.c_[np.ones(len(X)),X]

# %%
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(Y)

# %%
theta
# Out:
# array([24.03310617, -0.41519028])

# %%
plt.scatter(X[:,1],Y)
plt.plot(X[:,1],X.dot(theta), "r-")
plt.show()

# %%
X = np.c_[X, np.power(X[:,1],2)]
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(Y)

# %%
plt.scatter(X[:,1],Y)
plt.scatter(X[:,1] , X.dot(theta) , edgecolor="r")
plt.show()

# %%
X = np.c_[X, np.power(X[:,1],3), np.power(X[:,1],4), np.power(X[:,1],5), np.power(X[:,1],6), np.power(X[:,1],7), np.power(X[:,1],8)]
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(Y)

# %%
plt.scatter(X[:,1],Y)
plt.scatter(X[:,1] , X.dot(theta) , edgecolor="r")
plt.show()
