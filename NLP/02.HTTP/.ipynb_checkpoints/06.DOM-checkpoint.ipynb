# %%
from bs4 import BeautifulSoup

# %%
# html.parser
# lxml ***
# lxml-xml, xml
# html5lib

# %%
import requests
# 200 => OK
# 400 => My Fault
# 500 => You Fault => Traffic 과도하게 증가
header={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; WOW64; Trident/7.0; rv:11.0) like Gecko"}

def download(url, params ={}, retries = 3) :
    resp = None
    try :
        resp = requests.get(url, params = params, headers = header)
        resp.raise_for_status()
    except requests.exceptions.HTTPError as e :
        if 500 <= e.response.status_code < 600 and retries > 0:
            print(retries)
            resp = download(url, params, retries - 1)
        else :
            print(e.response.status_code)
            print(e.response.reason)
            print(e.response.headers)
    
    return resp

# %%
html = """
<html>
<head></head>
<body>
    <div id=test></div>
    <div id="result">
        <p class="row">
            <a class="red">go to page1</a>
            <a class="blue">go to page2</a>
    </div>

</body>
</html>
"""

# %%
from bs4 import BeautifulSoup
dom = BeautifulSoup(html,"lxml")

# %%
dom.div["id"], dom.a["class"], type(dom.div), type(dom.span)
# Out:
# ('test', ['red'], bs4.element.Tag, NoneType)

# %%
try :
    dom.span.attr
except AttributeError as e :
    print("Not Found")
# Out:
# Not Found

# %%
dom.html.body.p, dom.p, [_ for _ in dom.p.children]
# Out:
# (<p class="row">
#  <a class="red">go to page1</a>
#  <a class="blue">go to page2</a>
#  </p>, <p class="row">
#  <a class="red">go to page1</a>
#  <a class="blue">go to page2</a>
#  </p>, ['\n',
#   <a class="red">go to page1</a>,
#   '\n',
#   <a class="blue">go to page2</a>,
#   '\n'])

# %%
dom.prettify()
# Out:
# '<html>\n <head>\n </head>\n <body>\n  <div>\n  </div>\n  <div id="result">\n   <p class="row">\n    <a class="red">\n     go to page1\n    </a>\n    <a class="blue">\n     go to page2\n    </a>\n   </p>\n  </div>\n </body>\n</html>\n'

# %%
dom.h1, dom.h2, dom.h3, dom.h4
try:
    print(dom.h4.text)
except AttributeError as e :
    print(dom.h3.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-cacf4d3ca95f> in <module>
#       2 try:
# ----> 3     print(dom.h4.text)
#       4 except AttributeError as e:
#
# AttributeError: 'NoneType' object has no attribute 'text'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-cacf4d3ca95f> in <module>
#       3     print(dom.h4.text)
#       4 except AttributeError as e:
# ----> 5     print(dom.h3.text)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
dom.find("a")
# Out:
# <a class="red">go to page1</a>

# %%
dom.find_all("a"),\
dom.find_all("p")
# Out:
# ([<a class="red">go to page1</a>, <a class="blue">go to page2</a>],
#  [<p class="row">
#   <a class="red">go to page1</a>
#   <a class="blue">go to page2</a>
#   </p>])

# %%
dom.find_all({"div","p"}), \
dom.find_all("div",{"id":"result"}), \
dom.find_all("",attrs={"class":"red"}), \
dom.find_all("a", recursive=False), \
dom.find_all(text="go to page1"),\
dom.find_all("a", limit=2), \
dom.find_all("a", limit=1)
# Out:
# ([<div id="test"></div>, <div id="result">
#   <p class="row">
#   <a class="red">go to page1</a>
#   <a class="blue">go to page2</a>
#   </p></div>, <p class="row">
#   <a class="red">go to page1</a>
#   <a class="blue">go to page2</a>
#   </p>], [<div id="result">
#   <p class="row">
#   <a class="red">go to page1</a>
#   <a class="blue">go to page2</a>
#   </p></div>], [<a class="red">go to page1</a>], [], ['go to page1'], [<a class="red">go to page1</a>,
#   <a class="blue">go to page2</a>], [<a class="red">go to page1</a>])

# %%
dom.find("a",{"red":"blue"})

# %%
html = download("http://pythonscraping.com/pages/page3.html")
exercise = BeautifulSoup(html.text,"lxml")

# %%
exercise
# Out:
# <html>
# <head>
# <style>
# img{
# 	width:75px;
# }
# table{
# 	width:50%;
# }
# td{
# 	margin:10px;
# 	padding:10px;
# }
# .wrapper{
# 	width:800px;
# }
# .excitingNote{
# 	font-style:italic;
# 	font-weight:bold;
# }
# </style>
# </head>
# <body>
# <div id="wrapper">
# <img src="../img/gifts/logo.jpg" style="float:left;"/>
# <h1>Totally Normal Gifts</h1>
# <div id="content">Here is a collection of totally normal, totally reasonable gifts that your friends are sure to love! Our collection is
# hand-curated by well-paid, free-range Tibetan monks.<p>
# We haven't figured out how to make online shopping carts yet, but you can send us a check to:<br/>
# 123 Main St.<br/>
# Abuja, Nigeria
# We will then send your totally amazing gift, pronto! Please include an extra $5.00 for gift wrapping.</p></div>
# <table id="giftList">
# <tr><th>
# Item Title
# </th><th>
# Description
# </th><th>
# Cost
# </th><th>
# Image
# </th></tr>
# <tr class="gift" id="gift1"><td>
# Vegetable Basket
# </td><td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td><td>
# $15.00
# </td><td>
# <img src="../img/gifts/img1.jpg"/>
# </td></tr>
# <tr class="gift" id="gift2"><td>
# Russian Nesting Dolls
# </td><td>
# Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
# </td><td>
# $10,000.52
# </td><td>
# <img src="../img/gifts/img2.jpg"/>
# </td></tr>
# <tr class="gift" id="gift3"><td>
# Fish Painting
# </td><td>
# If something seems fishy about this painting, it's because it's a fish! <span class="excitingNote">Also hand-painted by trained monkeys!</span>
# </td><td>
# $10,005.00
# </td><td>
# <img src="../img/gifts/img3.jpg"/>
# </td></tr>
# <tr class="gift" id="gift4"><td>
# Dead Parrot
# </td><td>
# This is an ex-parrot! <span class="excitingNote">Or maybe he's only resting?</span>
# </td><td>
# $0.50
# </td><td>
# <img src="../img/gifts/img4.jpg"/>
# </td></tr>
# <tr class="gift" id="gift5"><td>
# Mystery Box
# </td><td>
# If you love suprises, this mystery box is for you! Do not place on light-colored surfaces. May cause oil staining. <span class="excitingNote">Keep your friends guessing!</span>
# </td><td>
# $1.50
# </td><td>
# <img src="../img/gifts/img6.jpg"/>
# </td></tr>
# </table>
# <div id="footer">
# © Totally Normal Gifts, Inc. <br/>
# +234 (617) 863-0736
# </div>
# </div>
# </body>
# </html>

# %%
footer = exercise.find("", {"id":"footer"})
footer
# Out:
# <div id="footer">
# © Totally Normal Gifts, Inc. <br/>
# +234 (617) 863-0736
# </div>

# %%
footer.name, footer["id"], \
footer.find_parent().name, footer.find_parent()["id"], \
footer.find_parent().find_parent().name #(.name=태그이름)(.attr)
# Out:
# ('div', 'footer', 'div', 'wrapper', 'body')

# %%
footer.find_parent()["id"]
# Out:
# 'wrapper'

# %%
parent = footer.find_parent()
parent.name , parent.attrs
# Out:
# ('div', {'id': 'wrapper'})

# %%
[ _.name for _ in parent.find_all()]
# Out:
# ['img',
#  'h1',
#  'div',
#  'p',
#  'br',
#  'br',
#  'table',
#  'tr',
#  'th',
#  'th',
#  'th',
#  'th',
#  'tr',
#  'td',
#  'td',
#  'span',
#  'td',
#  'td',
#  'img',
#  'tr',
#  'td',
#  'td',
#  'span',
#  'td',
#  'td',
#  'img',
#  'tr',
#  'td',
#  'td',
#  'span',
#  'td',
#  'td',
#  'img',
#  'tr',
#  'td',
#  'td',
#  'span',
#  'td',
#  'td',
#  'img',
#  'tr',
#  'td',
#  'td',
#  'span',
#  'td',
#  'td',
#  'img',
#  'div',
#  'br']

# %%
[_.name for _ in footer.find_previous_siblings()]
# Out:
# ['table', 'div', 'h1', 'img']

# %%
parent.find_all(recursive=False)[3]
# Out:
# <table id="giftList">
# <tr><th>
# Item Title
# </th><th>
# Description
# </th><th>
# Cost
# </th><th>
# Image
# </th></tr>
# <tr class="gift" id="gift1"><td>
# Vegetable Basket
# </td><td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td><td>
# $15.00
# </td><td>
# <img src="../img/gifts/img1.jpg"/>
# </td></tr>
# <tr class="gift" id="gift2"><td>
# Russian Nesting Dolls
# </td><td>
# Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
# </td><td>
# $10,000.52
# </td><td>
# <img src="../img/gifts/img2.jpg"/>
# </td></tr>
# <tr class="gift" id="gift3"><td>
# Fish Painting
# </td><td>
# If something seems fishy about this painting, it's because it's a fish! <span class="excitingNote">Also hand-painted by trained monkeys!</span>
# </td><td>
# $10,005.00
# </td><td>
# <img src="../img/gifts/img3.jpg"/>
# </td></tr>
# <tr class="gift" id="gift4"><td>
# Dead Parrot
# </td><td>
# This is an ex-parrot! <span class="excitingNote">Or maybe he's only resting?</span>
# </td><td>
# $0.50
# </td><td>
# <img src="../img/gifts/img4.jpg"/>
# </td></tr>
# <tr class="gift" id="gift5"><td>
# Mystery Box
# </td><td>
# If you love suprises, this mystery box is for you! Do not place on light-colored surfaces. May cause oil staining. <span class="excitingNote">Keep your friends guessing!</span>
# </td><td>
# $1.50
# </td><td>
# <img src="../img/gifts/img6.jpg"/>
# </td></tr>
# </table>

# %%
exercise.table.name, exercise.find("table").name
# Out:
# ('table', 'table')

# %%
[_.text.strip() for _ in parent.find_all(recursive=False)][3]
# Out:
# 'Item Title\n\nDescription\n\nCost\n\nImage\n\n\nVegetable Basket\n\nThis vegetable basket is the perfect gift for your health conscious (or overweight) friends!\nNow with super-colorful bell peppers!\n\n$15.00\n\n\n\n\nRussian Nesting Dolls\n\nHand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! 8 entire dolls per set! Octuple the presents!\n\n$10,000.52\n\n\n\n\nFish Painting\n\nIf something seems fishy about this painting, it\'s because it\'s a fish! Also hand-painted by trained monkeys!\n\n$10,005.00\n\n\n\n\nDead Parrot\n\nThis is an ex-parrot! Or maybe he\'s only resting?\n\n$0.50\n\n\n\n\nMystery Box\n\nIf you love suprises, this mystery box is for you! Do not place on light-colored surfaces. May cause oil staining. Keep your friends guessing!\n\n$1.50'

# %%
table = footer.find_previous_sibling()
tr = table.find_all("tr", {"class":"gift"})
for _ in tr :
    print(_.find_all(recursive=False)[2].text.strip())
# Out:
# $15.00
# $10,000.52
# $10,005.00
# $0.50
# $1.50

# %%
exercise.find_all()
# Out:
# [<html>
#  <head>
#  <style>
#  img{
#  	width:75px;
#  }
#  table{
#  	width:50%;
#  }
#  td{
#  	margin:10px;
#  	padding:10px;
#  }
#  .wrapper{
#  	width:800px;
#  }
#  .excitingNote{
#  	font-style:italic;
#  	font-weight:bold;
#  }
#  </style>
#  </head>
#  <body>
#  <div id="wrapper">
#  <img src="../img/gifts/logo.jpg" style="float:left;"/>
#  <h1>Totally Normal Gifts</h1>
#  <div id="content">Here is a collection of totally normal, totally reasonable gifts that your friends are sure to love! Our collection is
#  hand-curated by well-paid, free-range Tibetan monks.<p>
#  We haven't figured out how to make online shopping carts yet, but you can send us a check to:<br/>
#  123 Main St.<br/>
#  Abuja, Nigeria
#  We will then send your totally amazing gift, pronto! Please include an extra $5.00 for gift wrapping.</p></div>
#  <table id="giftList">
#  <tr><th>
#  Item Title
#  </th><th>
#  Description
#  </th><th>
#  Cost
#  </th><th>
#  Image
#  </th></tr>
#  <tr class="gift" id="gift1"><td>
#  Vegetable Basket
#  </td><td>
#  This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
#  <span class="excitingNote">Now with super-colorful bell peppers!</span>
#  </td><td>
#  $15.00
#  </td><td>
#  <img src="../img/gifts/img1.jpg"/>
#  </td></tr>
#  <tr class="gift" id="gift2"><td>
#  Russian Nesting Dolls
#  </td><td>
#  Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
#  </td><td>
#  $10,000.52
#  </td><td>
#  <img src="../img/gifts/img2.jpg"/>
#  </td></tr>
#  <tr class="gift" id="gift3"><td>
#  Fish Painting
#  </td><td>
#  If something seems fishy about this painting, it's because it's a fish! <span class="excitingNote">Also hand-painted by trained monkeys!</span>
#  </td><td>
#  $10,005.00
#  </td><td>
#  <img src="../img/gifts/img3.jpg"/>
#  </td></tr>
#  <tr class="gift" id="gift4"><td>
#  Dead Parrot
#  </td><td>
#  This is an ex-parrot! <span class="excitingNote">Or maybe he's only resting?</span>
#  </td><td>
#  $0.50
#  </td><td>
#  <img src="../img/gifts/img4.jpg"/>
#  </td></tr>
#  <tr class="gift" id="gift5"><td>
#  Mystery Box
#  </td><td>
#  If you love suprises, this mystery box is for you! Do not place on light-colored surfaces. May cause oil staining. <span class="excitingNote">Keep your friends guessing!</span>
#  </td><td>
#  $1.50
#  </td><td>
#  <img src="../img/gifts/img6.jpg"/>
#  </td></tr>
#  </table>
#  <div id="footer">
#  © Totally Normal Gifts, Inc. <br/>
#  +234 (617) 863-0736
#  </div>
#  </div>
#  </body>
#  </html>, <head>
#  <style>
#  img{
#  	width:75px;
#  }
#  table{
#  	width:50%;
#  }
#  td{
#  	margin:10px;
#  	padding:10px;
#  }
#  .wrapper{
#  	width:800px;
#  }
#  .excitingNote{
#  	font-style:italic;
#  	font-weight:bold;
#  }
#  </style>
#  </head>, <style>
#  img{
#  	width:75px;
#  }
#  table{
#  	width:50%;
#  }
#  td{
#  	margin:10px;
#  	padding:10px;
#  }
#  .wrapper{
#  	width:800px;
#  }
#  .excitingNote{
#  	font-style:italic;
#  	font-weight:bold;
#  }
#  </style>, <body>
#  <div id="wrapper">
#  <img src="../img/gifts/logo.jpg" style="float:left;"/>
#  <h1>Totally Normal Gifts</h1>
#  <div id="content">Here is a collection of totally normal, totally reasonable gifts that your friends are sure to love! Our collection is
#  hand-curated by well-paid, free-range Tibetan monks.<p>
#  We haven't figured out how to make online shopping carts yet, but you can send us a check to:<br/>
#  123 Main St.<br/>
#  Abuja, Nigeria
#  We will then send your totally amazing gift, pronto! Please include an extra $5.00 for gift wrapping.</p></div>
#  <table id="giftList">
#  <tr><th>
#  Item Title
#  </th><th>
#  Description
#  </th><th>
#  Cost
#  </th><th>
#  Image
#  </th></tr>
#  <tr class="gift" id="gift1"><td>
#  Vegetable Basket
#  </td><td>
#  This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
#  <span class="excitingNote">Now with super-colorful bell peppers!</span>
#  </td><td>
#  $15.00
#  </td><td>
#  <img src="../img/gifts/img1.jpg"/>
#  </td></tr>
#  <tr class="gift" id="gift2"><td>
#  Russian Nesting Dolls
#  </td><td>
#  Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
#  </td><td>
#  $10,000.52
#  </td><td>
#  <img src="../img/gifts/img2.jpg"/>
#  </td></tr>
#  <tr class="gift" id="gift3"><td>
#  Fish Painting
#  </td><td>
#  If something seems fishy about this painting, it's because it's a fish! <span class="excitingNote">Also hand-painted by trained monkeys!</span>
#  </td><td>
#  $10,005.00
#  </td><td>
#  <img src="../img/gifts/img3.jpg"/>
#  </td></tr>
#  <tr class="gift" id="gift4"><td>
#  Dead Parrot
#  </td><td>
#  This is an ex-parrot! <span class="excitingNote">Or maybe he's only resting?</span>
#  </td><td>
#  $0.50
#  </td><td>
#  <img src="../img/gifts/img4.jpg"/>
#  </td></tr>
#  <tr class="gift" id="gift5"><td>
#  Mystery Box
#  </td><td>
#  If you love suprises, this mystery box is for you! Do not place on light-colored surfaces. May cause oil staining. <span class="excitingNote">Keep your friends guessing!</span>
#  </td><td>
#  $1.50
#  </td><td>
#  <img src="../img/gifts/img6.jpg"/>
#  </td></tr>
#  </table>
#  <div id="footer">
#  © Totally Normal Gifts, Inc. <br/>
#  +234 (617) 863-0736
#  </div>
#  </div>
#  </body>, <div id="wrapper">
#  <img src="../img/gifts/logo.jpg" style="float:left;"/>
#  <h1>Totally Normal Gifts</h1>
#  <div id="content">Here is a collection of totally normal, totally reasonable gifts that your friends are sure to love! Our collection is
#  hand-curated by well-paid, free-range Tibetan monks.<p>
#  We haven't figured out how to make online shopping carts yet, but you can send us a check to:<br/>
#  123 Main St.<br/>
#  Abuja, Nigeria
#  We will then send your totally amazing gift, pronto! Please include an extra $5.00 for gift wrapping.</p></div>
#  <table id="giftList">
#  <tr><th>
#  Item Title
#  </th><th>
#  Description
#  </th><th>
#  Cost
#  </th><th>
#  Image
#  </th></tr>
#  <tr class="gift" id="gift1"><td>
#  Vegetable Basket
#  </td><td>
#  This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
#  <span class="excitingNote">Now with super-colorful bell peppers!</span>
#  </td><td>
#  $15.00
#  </td><td>
#  <img src="../img/gifts/img1.jpg"/>
#  </td></tr>
#  <tr class="gift" id="gift2"><td>
#  Russian Nesting Dolls
#  </td><td>
#  Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
#  </td><td>
#  $10,000.52
#  </td><td>
#  <img src="../img/gifts/img2.jpg"/>
#  </td></tr>
#  <tr class="gift" id="gift3"><td>
#  Fish Painting
#  </td><td>
#  If something seems fishy about this painting, it's because it's a fish! <span class="excitingNote">Also hand-painted by trained monkeys!</span>
#  </td><td>
#  $10,005.00
#  </td><td>
#  <img src="../img/gifts/img3.jpg"/>
#  </td></tr>
#  <tr class="gift" id="gift4"><td>
#  Dead Parrot
#  </td><td>
#  This is an ex-parrot! <span class="excitingNote">Or maybe he's only resting?</span>
#  </td><td>
#  $0.50
#  </td><td>
#  <img src="../img/gifts/img4.jpg"/>
#  </td></tr>
#  <tr class="gift" id="gift5"><td>
#  Mystery Box
#  </td><td>
#  If you love suprises, this mystery box is for you! Do not place on light-colored surfaces. May cause oil staining. <span class="excitingNote">Keep your friends guessing!</span>
#  </td><td>
#  $1.50
#  </td><td>
#  <img src="../img/gifts/img6.jpg"/>
#  </td></tr>
#  </table>
#  <div id="footer">
#  © Totally Normal Gifts, Inc. <br/>
#  +234 (617) 863-0736
#  </div>
#  </div>, <img src="../img/gifts/logo.jpg" style="float:left;"/>, <h1>Totally Normal Gifts</h1>, <div id="content">Here is a collection of totally normal, totally reasonable gifts that your friends are sure to love! Our collection is
#  hand-curated by well-paid, free-range Tibetan monks.<p>
#  We haven't figured out how to make online shopping carts yet, but you can send us a check to:<br/>
#  123 Main St.<br/>
#  Abuja, Nigeria
#  We will then send your totally amazing gift, pronto! Please include an extra $5.00 for gift wrapping.</p></div>, <p>
#  We haven't figured out how to make online shopping carts yet, but you can send us a check to:<br/>
#  123 Main St.<br/>
#  Abuja, Nigeria
#  We will then send your totally amazing gift, pronto! Please include an extra $5.00 for gift wrapping.</p>, <br/>, <br/>, <table id="giftList">
#  <tr><th>
#  Item Title
#  </th><th>
#  Description
#  </th><th>
#  Cost
#  </th><th>
#  Image
#  </th></tr>
#  <tr class="gift" id="gift1"><td>
#  Vegetable Basket
#  </td><td>
#  This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
#  <span class="excitingNote">Now with super-colorful bell peppers!</span>
#  </td><td>
#  $15.00
#  </td><td>
#  <img src="../img/gifts/img1.jpg"/>
#  </td></tr>
#  <tr class="gift" id="gift2"><td>
#  Russian Nesting Dolls
#  </td><td>
#  Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
#  </td><td>
#  $10,000.52
#  </td><td>
#  <img src="../img/gifts/img2.jpg"/>
#  </td></tr>
#  <tr class="gift" id="gift3"><td>
#  Fish Painting
#  </td><td>
#  If something seems fishy about this painting, it's because it's a fish! <span class="excitingNote">Also hand-painted by trained monkeys!</span>
#  </td><td>
#  $10,005.00
#  </td><td>
#  <img src="../img/gifts/img3.jpg"/>
#  </td></tr>
#  <tr class="gift" id="gift4"><td>
#  Dead Parrot
#  </td><td>
#  This is an ex-parrot! <span class="excitingNote">Or maybe he's only resting?</span>
#  </td><td>
#  $0.50
#  </td><td>
#  <img src="../img/gifts/img4.jpg"/>
#  </td></tr>
#  <tr class="gift" id="gift5"><td>
#  Mystery Box
#  </td><td>
#  If you love suprises, this mystery box is for you! Do not place on light-colored surfaces. May cause oil staining. <span class="excitingNote">Keep your friends guessing!</span>
#  </td><td>
#  $1.50
#  </td><td>
#  <img src="../img/gifts/img6.jpg"/>
#  </td></tr>
#  </table>, <tr><th>
#  Item Title
#  </th><th>
#  Description
#  </th><th>
#  Cost
#  </th><th>
#  Image
#  </th></tr>, <th>
#  Item Title
#  </th>, <th>
#  Description
#  </th>, <th>
#  Cost
#  </th>, <th>
#  Image
#  </th>, <tr class="gift" id="gift1"><td>
#  Vegetable Basket
#  </td><td>
#  This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
#  <span class="excitingNote">Now with super-colorful bell peppers!</span>
#  </td><td>
#  $15.00
#  </td><td>
#  <img src="../img/gifts/img1.jpg"/>
#  </td></tr>, <td>
#  Vegetable Basket
#  </td>, <td>
#  This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
#  <span class="excitingNote">Now with super-colorful bell peppers!</span>
#  </td>, <span class="excitingNote">Now with super-colorful bell peppers!</span>, <td>
#  $15.00
#  </td>, <td>
#  <img src="../img/gifts/img1.jpg"/>
#  </td>, <img src="../img/gifts/img1.jpg"/>, <tr class="gift" id="gift2"><td>
#  Russian Nesting Dolls
#  </td><td>
#  Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
#  </td><td>
#  $10,000.52
#  </td><td>
#  <img src="../img/gifts/img2.jpg"/>
#  </td></tr>, <td>
#  Russian Nesting Dolls
#  </td>, <td>
#  Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
#  </td>, <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>, <td>
#  $10,000.52
#  </td>, <td>
#  <img src="../img/gifts/img2.jpg"/>
#  </td>, <img src="../img/gifts/img2.jpg"/>, <tr class="gift" id="gift3"><td>
#  Fish Painting
#  </td><td>
#  If something seems fishy about this painting, it's because it's a fish! <span class="excitingNote">Also hand-painted by trained monkeys!</span>
#  </td><td>
#  $10,005.00
#  </td><td>
#  <img src="../img/gifts/img3.jpg"/>
#  </td></tr>, <td>
#  Fish Painting
#  </td>, <td>
#  If something seems fishy about this painting, it's because it's a fish! <span class="excitingNote">Also hand-painted by trained monkeys!</span>
#  </td>, <span class="excitingNote">Also hand-painted by trained monkeys!</span>, <td>
#  $10,005.00
#  </td>, <td>
#  <img src="../img/gifts/img3.jpg"/>
#  </td>, <img src="../img/gifts/img3.jpg"/>, <tr class="gift" id="gift4"><td>
#  Dead Parrot
#  </td><td>
#  This is an ex-parrot! <span class="excitingNote">Or maybe he's only resting?</span>
#  </td><td>
#  $0.50
#  </td><td>
#  <img src="../img/gifts/img4.jpg"/>
#  </td></tr>, <td>
#  Dead Parrot
#  </td>, <td>
#  This is an ex-parrot! <span class="excitingNote">Or maybe he's only resting?</span>
#  </td>, <span class="excitingNote">Or maybe he's only resting?</span>, <td>
#  $0.50
#  </td>, <td>
#  <img src="../img/gifts/img4.jpg"/>
#  </td>, <img src="../img/gifts/img4.jpg"/>, <tr class="gift" id="gift5"><td>
#  Mystery Box
#  </td><td>
#  If you love suprises, this mystery box is for you! Do not place on light-colored surfaces. May cause oil staining. <span class="excitingNote">Keep your friends guessing!</span>
#  </td><td>
#  $1.50
#  </td><td>
#  <img src="../img/gifts/img6.jpg"/>
#  </td></tr>, <td>
#  Mystery Box
#  </td>, <td>
#  If you love suprises, this mystery box is for you! Do not place on light-colored surfaces. May cause oil staining. <span class="excitingNote">Keep your friends guessing!</span>
#  </td>, <span class="excitingNote">Keep your friends guessing!</span>, <td>
#  $1.50
#  </td>, <td>
#  <img src="../img/gifts/img6.jpg"/>
#  </td>, <img src="../img/gifts/img6.jpg"/>, <div id="footer">
#  © Totally Normal Gifts, Inc. <br/>
#  +234 (617) 863-0736
#  </div>, <br/>]

# %%
for _ in exercise.find_all("tr",{"class":"gift"}):
    print(_.find_all(recursive=False)[2].text.strip())
# Out:
# $15.00
# $10,000.52
# $10,005.00
# $0.50
# $1.50

# %%
import re
[_.text.strip() for _ in exercise.find_all("td", text=re.compile("[0-9]+.\d+"))]
# Out:
# ['$15.00', '$10,000.52', '$10,005.00', '$0.50', '$1.50']

# %%
[ _["src"].text.strip() for _ in exercise.find_all("img",{"src":re.compile("../img/gifts/img/d+.jpg")})]
# Out:
# []

# %%
[ _ for _ in exercise.find_all("img",{"src":re.compile("../img/gifts/img\d+.jpg")})]
# Out:
# [<img src="../img/gifts/img1.jpg"/>,
#  <img src="../img/gifts/img2.jpg"/>,
#  <img src="../img/gifts/img3.jpg"/>,
#  <img src="../img/gifts/img4.jpg"/>,
#  <img src="../img/gifts/img6.jpg"/>]

# %%
requests.compat.urljoin(html.request.url,"page")
# Out:
# 'http://pythonscraping.com/pages/page'

# %%
"구글검색결과 , 네이버검색결과"
# Out:
# '구글검색결과 , 네이버검색결과'

# %%
html = download("http://www.google.com.com/search",{"q":"박보영"})
google = BeautifulSoup(html.text,"lxml")
#len(google.find_all("h3",{"class":"LC201b"}))

# %%
result = list()
for _ in google.find_all("h3",{"class":"LC201b"}):
    result.append((_.text.strip(),_.find_parent()["href"]))
    #print(_.text.strip())
    #print(_.find_parent()["href"])

# %%
[ _ for h3 in google.find_all("h3",{"class":"LC201b"})]

# %%
html = download("https://search.naver.com/search.naver",{"query":"박보영","oquery":"박보영"})
naver = BeautifulSoup(html.text,"lxml")

# %%
naver.text
# Out:
# '          박보영 : 네이버 통합검색     naver = window.naver || {}; naver.search = naver.search || {}; var g_D = 0 ; if (!String.prototype.trim) { String.prototype.trim = function () { return this.replace(/^[\\s\\uFEFF\\xA0]+|[\\s\\uFEFF\\xA0]+$/g, \'\'); }; } function urlencode (q) { return escape(q).replace(/\\+/g, "%2B") ; } function urlexpand (url) { var href = document.location.href ; if (url == "") return href ; if (url.match(/^[-.A-Za-z]+:/)) return url ; if (url.charAt(0) == \'#\') return href.split("#")[0] + url ; if (url.charAt(0) == \'?\') return href.split("?")[0] + url ; if (url.charAt(0) == \'/\') return href.replace(/([^:\\/])\\/.*$/, "$1") + url ; return href.substring(0, href.lastIndexOf("/")+1) + url ; } naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === \'undefined\') d = \'|\' ; return errorList.join(d) ; } } })(); naver.search.cookie = (function () { return { set : function (key, value, expire, domain) { var cookie = key + "=" + escape(value); if (typeof expire !== \'undefined\') { if (expire instanceof Date) { cookie = cookie + "; expires=" + expire.toUTCString(); } else { var exdate = new Date((new Date()).getTime() + expire*1000); cookie = cookie + "; expires=" + exdate.toUTCString(); } } cookie = cookie + "; path=/"; if (domain != null) { cookie = cookie + "; domain=" + domain; } document.cookie = cookie; }, get : function (key) { var cookie_list = document.cookie.split(/\\s*;\\s*/); for (var i = 0; i < cookie_list.length; i++) { var tmp_list = cookie_list[i].split("="); var c_key = tmp_list[0].trim(); var c_value = tmp_list[1]; if (key == c_key) { return unescape(c_value); } } return null; } } })(); naver.search.https = window.location.protocol == "https:"; naver.search.meta_referrer = 0; var _nx_js_load = (function () { var scrs = {} ; return function (script, callback) { scrs[script] = {} ; scrs[script].domscript = document.createElement(\'script\'); scrs[script].domscript.src = script ; if (callback) scrs[script].callback = (callback instanceof Array) ? callback : [callback]; scrs[script].domscript.onloadDone = false; scrs[script].domscript.onload = function() { scrs[script].domscript.onloadDone = true; if (scrs[script].callback) { for (var i = 0; i < scrs[script].callback.length; i++) { scrs[script].callback[i]() ; } } scrs[script].domscript.onload = scrs[script].domscript.onreadystatechange = null; } ; scrs[script].domscript.onreadystatechange = function() { if ( ("loaded" === scrs[script].domscript.readyState || "complete" === scrs[script].domscript.readyState) && !scrs[script].domscript.onloadDone ) { scrs[script].domscript.onload(); } } ; document.getElementsByTagName(\'head\')[0].appendChild(scrs[script].domscript); }; })() ; var nx_js_defer_load = (function() { var info = {} ; return function(scrname, callback, t) { var nx_load_once = (function() { return function(scrname) { if (info[scrname].t > 0) setTimeout(function() { _nx_js_load(scrname, info[scrname].callback) ; }, t) ; else _nx_js_load(scrname, info[scrname].callback) ; } ; })(); if (t < 0) t = 0 ; if (info[scrname]) { n = info[scrname].length; for (var i = 0; i < n; i++) { if (info[scrname][i] == callback) return ; } if (t < info[scrname].t) info[scrname].t = t ; } else { info[scrname] = {} ; info[scrname].callback = [] ; info[scrname].t = t ; jindo.$Fn(function() { nx_load_once(scrname) ; }).attach(window, "load") ; } info[scrname].callback.push(callback) ; }; })(); function nx_js_lazyload(scripts, onload, is_serial) { if (!(scripts instanceof Array)) { scripts = [scripts]; } if (is_serial) { function load_next() { if (scripts.length == 0) { onload(); return; } _nx_js_load( scripts.shift(), load_next ) ; } load_next(); } else { var load_check = function() { var num_js = scripts.length; return function() { num_js--; if (num_js <= 0) { onload(); } } }( ...

# %%
import re
[ _ for _ in naver.find_all("li",{"id":re.compile("sp_nws_all\d")})]
# Out:
# [<li id="sp_nws_all1"> <div class="thumb"><a class="sp_thmb thmb80" href="http://news1.kr/articles/?3613110" onclick="return goOtherCR(this, 'a=nws_all*a.img&amp;r=1&amp;i=08138263_000000000000000003972619&amp;g=421.0003972619&amp;u='+urlencode(this.href));" target="_blank"><img alt='[N현장] "목표는 20%"' class="" height="80" onerror="this.parentNode.style.display='none';" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F421%2F2019%2F05%2F03%2F3972619.jpg&amp;type=ofullfill80_80_q75_re2" width="80"/><span class="thmb_v"></span></a></div> <dl> <dt><a class="_sp_each_title" href="http://news1.kr/articles/?3613110" onclick="return goOtherCR(this, 'a=nws_all*a.tit&amp;r=1&amp;i=08138263_000000000000000003972619&amp;g=421.0003972619&amp;u='+urlencode(this.href));" target="_blank" title="[N현장] &quot;목표는 20%&quot; 박보영X유제원 '어비스', '오나귀' 신드롬 재현할까(종합)">[N현장] "목표는 20%" <strong class="hl">박보영</strong>X유제원 '어비스', '오나귀' 신드롬 재현할까(종...</a></dt> <dd class="txt_inline"><span class="_sp_each_source">뉴스1</span> <span class="bar"></span> 6시간 전 <span class="bar"></span> <a class="_sp_each_url" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=106&amp;oid=421&amp;aid=0003972619" onclick="return goOtherCR(this, 'a=nws_all*a.nav&amp;r=1&amp;i=08138263_000000000000000003972619&amp;u='+urlencode(this.href));" target="_blank">네이버뉴스</a> <div class="scial" id="sp_nws_all1_base"> <span class="bar"></span> <a class="bt_scial2 naver-splugin" data-oninitialize="splugin_oninitialize('sp_nws_all1');" data-style="unity-v2" href="#" onclick="goOtherTCR(this, 'a=nws_all*a.pplugin&amp;r=1&amp;i=08138263_000000000000000003972619&amp;u='+urlencode(this.href)); return false;">보내기</a> </div> </dd> <dd>이 자리에는 유제원 PD와 배우 <strong class="hl">박보영</strong>, 안효섭, 이성재, 이시언이 참석해 취재진과 드라마에 대한 이야기를... 특히 '어비스'는 앞서 '오 나의 귀신님'을 통해 호흡을 맞춘 <strong class="hl">박보영</strong>과 유제원 PD의 재회작이라는 점에서 더욱...</dd> <dd> <ul class="relation_lst"> <li> <span class="ico_bu"></span> <a href="https://www.ytn.co.kr/_sn/0117_201905031542444999" onclick="return goOtherCR(this, 'a=nws_all*c.tit&amp;r=2&amp;i=880000AF_000000000000000001288761&amp;g=052.0001288761&amp;u='+urlencode(this.href));" target="_blank" title="[Y현장] '흔녀' 박보영·'남신' 안효섭이 그리는 판타지 로맨스, '어비스'(종합)">[Y현장] '흔녀' <strong class="hl">박보영</strong>·'남신' 안효섭이 그리는 판타지 로맨스, '어비스'(종...</a> <span class="txt_sinfo"> <span class="press" title="YTN">YTN</span> <span class="bar"></span> 5시간 전 <span class="bar"></span><a class="_sp_each_url" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=106&amp;oid=052&amp;aid=0001288761" onclick="return goOtherCR(this, 'a=nws_all*c.nav&amp;r=2&amp;i=880000AF_000000000000000001288761&amp;u='+urlencode(this.href));" target="_blank">네이버뉴스</a> </span> </li> <li> <span class="ico_bu"></span> <a href="http://sports.mk.co.kr/view.php?year=2019&amp;no=289759" onclick="return goOtherCR(this, 'a=nws_all*c.tit&amp;r=3&amp;i=88127054_000000000000000000581726&amp;g=410.0000581726&amp;u='+urlencode(this.href));" target="_blank" title="“박보영X유제원 PD 재회”..‘어비스’, ‘오나귀’ 열풍 재현할까(종합)">“<strong class="hl">박보영</strong>X유제원 PD 재회”..‘어비스’, ‘오나귀’ 열풍 재현할까(종합)</a> <span class="txt_sinfo"> <span class="press" title="MK스포츠">MK스포츠</span> <span class="bar"></span> 5시간 전 <span class="bar"></span><a class="_sp_each_url" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=106&amp;oid=410&amp;aid=0000581726" onclick="return goOtherCR(this, 'a=nws_all*c.nav&amp;r=3&amp;i=88127054_000000000000000000581726&amp;u='+urlencode(this.href));" target="_blank">네이버뉴스</a> </span> </li> </ul> <div class="newr_more"> <a class="more_news" href="?&amp;where=news&amp;sm=mtb_tnw&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81&amp;nso=so:r,p:all,a:all&amp;related=1&amp;docid=4210003972619" onclick="return goOtherCR(this, 'a=nws_all*r.more&amp;r=&amp;i=&amp;u='+urlencode(urlexpand(this.href)));">관련뉴스 전체보기</a> </div> </dd> </dl> </li>,
#  <li id="sp_nws_all4"> <div class="thumb"><a class="sp_thmb thmb80" href="http://star.mt.co.kr/stview.php?no=2019050313501862541" onclick="return goOtherCR(this, 'a=nws_all*a.img&amp;r=4&amp;i=880000C3_000000000000000002781149&amp;g=108.0002781149&amp;u='+urlencode(this.href));" target="_blank"><img alt="박보영X안효섭 ‘어비스" class="" height="80" onerror="this.parentNode.style.display='none';" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F108%2F2019%2F05%2F03%2F2781149.jpg&amp;type=ofullfill80_80_q75_re2" width="80"/><span class="thmb_v"></span></a></div> <dl> <dt><a class="_sp_each_title" href="http://star.mt.co.kr/stview.php?no=2019050313501862541" onclick="return goOtherCR(this, 'a=nws_all*a.tit&amp;r=4&amp;i=880000C3_000000000000000002781149&amp;g=108.0002781149&amp;u='+urlencode(this.href));" target="_blank" title="박보영X안효섭 '어비스', 이시언의 20% 소망 이뤄줄까[종합]"><strong class="hl">박보영</strong>X안효섭 '어비스', 이시언의 20% 소망 이뤄줄까[종합]</a></dt> <dd class="txt_inline"><span class="_sp_each_source">스타뉴스</span> <span class="bar"></span> 5시간 전 <span class="bar"></span> <a class="_sp_each_url" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=106&amp;oid=108&amp;aid=0002781149" onclick="return goOtherCR(this, 'a=nws_all*a.nav&amp;r=4&amp;i=880000C3_000000000000000002781149&amp;u='+urlencode(this.href));" target="_blank">네이버뉴스</a> <div class="scial" id="sp_nws_all4_base"> <span class="bar"></span> <a class="bt_scial2 naver-splugin" data-oninitialize="splugin_oninitialize('sp_nws_all4');" data-style="unity-v2" href="#" onclick="goOtherTCR(this, 'a=nws_all*a.pplugin&amp;r=4&amp;i=880000C3_000000000000000002781149&amp;u='+urlencode(this.href)); return false;">보내기</a> </div> </dd> <dd><strong class="hl">박보영</strong>, 안효섭 주연의 '어비스:영혼소생구슬'이 월화 안방극장 시청자들을 어떻게 사로잡을까. 3일 오후... '어비스'는 영혼 소생 구슬 어비스를 통해 생전과 180도 다른 반전 비주얼로 부활한 고세연(<strong class="hl">박보영</strong> 분), 차민...</dd> <dd> <ul class="relation_lst"> <li> <span class="ico_bu"></span> <a href="http://isplus.live.joins.com/news/article/aid.asp?aid=23050425" onclick="return goOtherCR(this, 'a=nws_all*c.tit&amp;r=5&amp;i=880002FC_000000000000000002909555&amp;g=241.0002909555&amp;u='+urlencode(this.href));" target="_blank" title="[포토]이성재-박보영-안효섭-이시언, 사랑스런 조합">[포토]이성재-<strong class="hl">박보영</strong>-안효섭-이시언, 사랑스런 조합</a> <span class="txt_sinfo"> <span class="press" title="일간스포츠">일간스포츠</span> <span class="bar"></span> 6시간 전 <span class="bar"></span><a class="_sp_each_url" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=106&amp;oid=241&amp;aid=0002909555" onclick="return goOtherCR(this, 'a=nws_all*c.nav&amp;r=5&amp;i=880002FC_000000000000000002909555&amp;u='+urlencode(this.href));" target="_blank">네이버뉴스</a> </span> </li> </ul> </dd> </dl> </li>,
#  <li id="sp_nws_all6"> <div class="thumb"><a class="sp_thmb thmb80" href="http://digitalchosun.dizzo.com/site/data/html_dir/2019/05/03/2019050380185.html" onclick="return goOtherCR(this, 'a=nws_all*b.img&amp;r=6&amp;i=88184407_000000000000000000006436&amp;g=5641.0000006436&amp;u='+urlencode(this.href));" target="_blank"><img alt="[HD영상] ‘어비스‘ 안" class="" height="80" onerror="this.parentNode.style.display='none';" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F5641%2F2019%2F05%2F03%2F6436.jpg&amp;type=ofullfill80_80_q75_re2" width="80"/><span class="thmb_v"></span></a></div> <dl> <dt><a class="_sp_each_url _sp_each_title" href="http://digitalchosun.dizzo.com/site/data/html_dir/2019/05/03/2019050380185.html" onclick="return goOtherCR(this, 'a=nws_all*b.tit&amp;r=6&amp;i=88184407_000000000000000000006436&amp;g=5641.0000006436&amp;u='+urlencode(this.href));" target="_blank" title="[HD영상] '어비스' 안효섭 &quot;'세젤흔녀' 박보영? 얼굴 보면 몰입 안 된다&quot;">[HD영상] '어비스' 안효섭 "'세젤흔녀' <strong class="hl">박보영</strong>? 얼굴 보면 몰입 안 된다"</a></dt> <dd class="txt_inline"><span class="_sp_each_source">디지틀조선일보</span> <span class="bar"></span> 4시간 전 <div class="scial" id="sp_nws_all6_base"> <span class="bar"></span> <a class="bt_scial2 naver-splugin" data-oninitialize="splugin_oninitialize('sp_nws_all6');" data-style="unity-v2" href="#" onclick="goOtherTCR(this, 'a=nws_all*b.pplugin&amp;r=6&amp;i=88184407_000000000000000000006436&amp;u='+urlencode(this.href)); return false;">보내기</a> </div> </dd> <dd>하나영 기자 | '어비스' 안효섭이 <strong class="hl">박보영</strong>의 얼굴과 '세젤흔녀'라는 수식어가 매치가 안 된다고 밝혔다. 3일... 극 중 <strong class="hl">박보영</strong>은 '상위 1% 여신 검사'에서 '세젤흔녀'(세상에서 제일 흔한 여자)로 부활한 고세연을 맡았으며...</dd> <dd> <ul class="relation_lst"> <li> <span class="ico_bu"></span> <a href="http://www.osen.co.kr/article/G1111135169" onclick="return goOtherCR(this, 'a=nws_all*c.tit&amp;r=7&amp;i=8800011B_000000000000000004002550&amp;g=109.0004002550&amp;u='+urlencode(this.href));" target="_blank" title="'어비스' 박보영 &quot;여신-세젤흔녀 연기, 김사랑과 차이 극대화했다&quot;">'어비스' <strong class="hl">박보영</strong> "여신-세젤흔녀 연기, 김사랑과 차이 극대화했다"</a> <span class="txt_sinfo"> <span class="press" title="OSEN">OSEN</span> <span class="bar"></span> 6시간 전 <span class="bar"></span><a class="" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=106&amp;oid=109&amp;aid=0004002550" onclick="return goOtherCR(this, 'a=nws_all*c.nav&amp;r=7&amp;i=8800011B_000000000000000004002550&amp;u='+urlencode(this.href));" target="_blank">네이버뉴스</a> </span> </li> <li> <span class="ico_bu"></span> <a href="http://www.sportsseoul.com/news/read/758699" onclick="return goOtherCR(this, 'a=nws_all*c.tit&amp;r=8&amp;i=88156f78_000000000000000000503518&amp;g=468.0000503518&amp;u='+urlencode(this.href));" target="_blank" title="'어비스' 박보영이 세젤흔女 외모? 안효섭 &quot;몰입하기 쉽지 않았다&quot;">'어비스' <strong class="hl">박보영</strong>이 세젤흔女 외모? 안효섭 "몰입하기 쉽지 않았다"</a> <span class="txt_sinfo"> <span class="press" title="스포츠서울">스포츠서울</span> <span class="bar"></span> 6시간 전 <span class="bar"></span><a class="" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=106&amp;oid=468&amp;aid=0000503518" onclick="return goOtherCR(this, 'a=nws_all*c.nav&amp;r=8&amp;i=88156f78_000000000000000000503518&amp;u='+urlencode(this.href));" target="_blank">네이버뉴스</a> </span> </li> </ul> <div class="newr_more"> <a class="more_news" href="?&amp;where=news&amp;sm=mtb_tnw&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81&amp;nso=so:r,p:all,a:all&amp;related=1&amp;docid=56410000006436" onclick="return goOtherCR(this, 'a=nws_all*r.more&amp;r=&amp;i=&amp;u='+urlencode(urlexpand(this.href)));">관련뉴스 전체보기</a> </div> </dd> </dl> </li>,
#  <li id="sp_nws_all9"> <div class="thumb"><a class="sp_thmb thmb80" href="http://star.mbn.co.kr/view.php?year=2019&amp;no=289721&amp;refer=portal" onclick="return goOtherCR(this, 'a=nws_all*a.img&amp;r=9&amp;i=880000BF_000000000000000001347581&amp;g=057.0001347581&amp;u='+urlencode(this.href));" target="_blank"><img alt="“흔녀된 뽀블리”…박" class="" height="80" onerror="this.parentNode.style.display='none';" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F057%2F2019%2F05%2F03%2F1347581.jpg&amp;type=ofullfill80_80_q75_re2" width="80"/><span class="thmb_v"></span></a></div> <dl> <dt><a class="_sp_each_title" href="http://star.mbn.co.kr/view.php?year=2019&amp;no=289721&amp;refer=portal" onclick="return goOtherCR(this, 'a=nws_all*a.tit&amp;r=9&amp;i=880000BF_000000000000000001347581&amp;g=057.0001347581&amp;u='+urlencode(this.href));" target="_blank" title="“흔녀된 뽀블리”…박보영X유제원 감독, ‘오나귀’ 잇는 신드롬 일으킬까(종합)">“흔녀된 뽀블리”…<strong class="hl">박보영</strong>X유제원 감독, ‘오나귀’ 잇는 신드롬 일으킬까(종...</a></dt> <dd class="txt_inline"><span class="_sp_each_source">MBN</span> <span class="bar"></span> 5시간 전 <span class="bar"></span> <a class="_sp_each_url" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=106&amp;oid=057&amp;aid=0001347581" onclick="return goOtherCR(this, 'a=nws_all*a.nav&amp;r=9&amp;i=880000BF_000000000000000001347581&amp;u='+urlencode(this.href));" target="_blank">네이버뉴스</a> <div class="scial" id="sp_nws_all9_base"> <span class="bar"></span> <a class="bt_scial2 naver-splugin" data-oninitialize="splugin_oninitialize('sp_nws_all9');" data-style="unity-v2" href="#" onclick="goOtherTCR(this, 'a=nws_all*a.pplugin&amp;r=9&amp;i=880000BF_000000000000000001347581&amp;u='+urlencode(this.href)); return false;">보내기</a> </div> </dd> <dd>뽀블리 <strong class="hl">박보영</strong>이 ‘어비스’를 통해 흔녀로 변신한다. 유제원 감독과의 재회로 ‘오나귀’를 잇는... 이날 현장에는 <strong class="hl">박보영</strong>, 안효섭, 이성재, 이시언, 유제원 감독이 참석했다. ‘어비스’는 ’영혼 소생 구슬’ 어비스를...</dd> <dd> <ul class="relation_lst"> <li> <span class="ico_bu"></span> <a href="http://www.mediasr.co.kr/news/articleView.html?idxno=52457" onclick="return goOtherCR(this, 'a=nws_all*d.tit&amp;r=10&amp;i=88188591_000000000000000000002566&amp;g=5670.0000002566&amp;u='+urlencode(this.href));" target="_blank" title="박보영 표 판타지 '어비스', 多장르로 그린 반전 비주얼 서스펜스"><strong class="hl">박보영</strong> 표 판타지 '어비스', 多장르로 그린 반전 비주얼 서스펜스</a> <span class="txt_sinfo"> <span class="press" title="미디어SR">미디어SR</span> <span class="bar"></span> 5시간 전 </span> </li> <li> <span class="ico_bu"></span> <a href="http://www.sisaweek.com/news/articleView.html?idxno=121417" onclick="return goOtherCR(this, 'a=nws_all*d.tit&amp;r=11&amp;i=88155e7e_000000000000000000094456&amp;g=5337.0000094456&amp;u='+urlencode(this.href));" target="_blank" title="['어비스' 현장] '뽀블리' 박보영, '세젤흔녀'가 되다">['어비스' 현장] '뽀블리' <strong class="hl">박보영</strong>, '세젤흔녀'가 되다</a> <span class="txt_sinfo"> <span class="press" title="시사위크">시사위크</span> <span class="bar"></span> 3시간 전 </span> </li> </ul> </dd> </dl> </li>]

# %%
result = list()
for _ in naver.find_all("dt"):
    #print("-".join([_.name for _ in _.find_parents(limit=4)]), "dl-li-ul-div", "-".join([_.name for _ in _.find_parents(limit=4)]) == "dl-li-ul-div")
    if "-".join([_.name for _ in _.find_parents(limit=4)]) == "dl-li-ul-div" :
        a = _.find("a")
        if a:
            print(a.text.strip())
            print(a["href"])
    #result.append((_.text.strip(),_.find_parent()["href"]))
    #print(_.find_parent()["href"])
# Out:
# 영화 너의결혼식 ...
# https://music.naver.com/album/index.nhn?albumId=2500698
# 오 나의 귀신님 ...
# https://music.naver.com/album/index.nhn?albumId=565464
# 고세연
# ?where=nexearch&sm=tab_etc&query=%EC%96%B4%EB%B9%84%EC%8A%A4%EA%B3%A0%EC%84%B8%EC%97%B0
# 도봉순
# ?where=nexearch&sm=tab_etc&query=%ED%9E%98%EC%8E%88%EC%97%AC%EC%9E%90%EB%8F%84%EB%B4%89%EC%88%9C%EB%8F%84%EB%B4%89%EC%88%9C
# [N현장] "목표는 20%" 박보영X유제원 '어비스', '오나귀' 신드롬 재현할까(종...
# http://news1.kr/articles/?3613110
# 박보영X안효섭 '어비스', 이시언의 20% 소망 이뤄줄까[종합]
# http://star.mt.co.kr/stview.php?no=2019050313501862541
# [HD영상] '어비스' 안효섭 "'세젤흔녀' 박보영? 얼굴 보면 몰입 안 된다"
# http://digitalchosun.dizzo.com/site/data/html_dir/2019/05/03/2019050380185.html
# “흔녀된 뽀블리”…박보영X유제원 감독, ‘오나귀’ 잇는 신드롬 일으킬까(종...
# http://star.mbn.co.kr/view.php?year=2019&no=289721&refer=portal
# '어비스' 안효섭, 박보영이 흔녀? '몰입하기...
# https://tv.naver.com/v/8245633
# '어비스' 이시언, 박보영 스킨십 장면 있는거...
# https://tv.naver.com/v/8245448
# '어비스' 박보영, '세젤흔녀' 연기.. 김사랑과...
# https://tv.naver.com/v/8245318
# '어비스' 박보영, 뽀블리가 마블리를...
# https://tv.naver.com/v/8245519
# 배우 박보영, 반할 수밖에 없는 청순 러블리
# https://m.post.naver.com/viewer/postView.nhn?volumeNo=19568466&memberNo=36645352&vType=VERTICAL
# 박보영에게‘무장해제’ 당한 상대 배우들
# https://m.post.naver.com/viewer/postView.nhn?volumeNo=17970239&memberNo=23519771&vType=VERTICAL
# 이 세상 사이즈가 아니라는 박보영 얼굴 크기 체감
# https://m.post.naver.com/viewer/postView.nhn?volumeNo=19260625&memberNo=22401813&vType=VERTICAL
# 박보영 이런 모습도 있네요?
# https://cafe.naver.com/imsanbu/44492596
# 2019.04.29 박보영 쏘피 바디피트 팬사인회 현장
# https://cafe.naver.com/linearbeit/43556
# 박보영은 언제쯤 결혼을 할까요?
# https://cafe.naver.com/momakakao/11285454
# 박보영 나오는 드라마 하나봐요
# https://cafe.naver.com/isajime/3995463
# 럭키슈에뜨 박보영 가디건
# https://cafe.naver.com/joonggonara/583117874
# 박보영 : 오 나의 귀신님 나봉선
# https://blog.naver.com/js2y86?Redirect=Log&logNo=221454815826
# [티저] 초면에 사랑합니다 vs 어비스 (김영광vs박보영)
# https://blog.naver.com/cuterobbie?Redirect=Log&logNo=221521796495
# 월화드라마 어비스로 돌아올 박보영 스타일에 대해 알아보자
# https://blog.naver.com/agaci01?Redirect=Log&logNo=221528823480
# 박보영 김영광 열애 나이와키 군대 미우새 출연
# https://skinous.tistory.com/entry/%EB%B0%95%EB%B3%B4%EC%98%81-%EA%B9%80%EC%98%81%EA%B4%91-%EC%97%B4%EC%95%A0-%EB%82%98%EC%9D%B4%EC%99%80%ED%82%A4-%EA%B5%B0%EB%8C%80-%EB%AF%B8%EC%9A%B0%EC%83%88-%EC%B6%9C%EC%97%B0
# 박보영 김영광 열애 키차이 아버지 군대 ?
# https://chearrr.tistory.com/entry/%EB%B0%95%EB%B3%B4%EC%98%81-%EA%B9%80%EC%98%81%EA%B4%91-%EC%97%B4%EC%95%A0-%ED%82%A4%EC%B0%A8%EC%9D%B4-%EC%95%84%EB%B2%84%EC%A7%80-%EA%B5%B0%EB%8C%80
# 제가 박보영 옛날 턱이락 똑같은데 어
# https://kin.naver.com/qna/detail.nhn?d1id=3&dirId=306&docId=325917258&qb=67CV67O07JiB&enc=utf8&section=kin&rank=1&search_sort=0&spq=1
# 박보영 이 사진 고화질 부탁 내공 5
# https://kin.naver.com/qna/detail.nhn?d1id=3&dirId=31402&docId=322399276&qb=67CV67O07JiB&enc=utf8&section=kin&rank=2&search_sort=0&spq=1
# 박보영 폰 배경사진 고화질로 여러장
# https://kin.naver.com/qna/detail.nhn?d1id=3&dirId=31401&docId=315877714&qb=67CV67O07JiB&enc=utf8&section=kin&rank=3&search_sort=0&spq=1
# 박보영 머리색깔
# https://kin.naver.com/qna/detail.nhn?d1id=8&dirId=8030203&docId=323375788&qb=67CV67O07JiB&enc=utf8&section=kin&rank=4&search_sort=0&spq=1
# 박보영 - 나무위키
# https://namu.wiki/w/%EB%B0%95%EB%B3%B4%EC%98%81
# 박보영 갤러리
# http://gall.dcinside.com/board/lists/?id=parkboyoung
# 박보영
# https://movie.daum.net/person/main?personId=105244

# %%
[ _.text.strip() for _ in naver.find_all("a",{"class":["_sp_each_title","sh_cafe_title","sh_blog_title","tit","title_link"]})]
# Out:
# ['[N현장] "목표는 20%" 박보영X유제원 \'어비스\', \'오나귀\' 신드롬 재현할까(종...',
#  "박보영X안효섭 '어비스', 이시언의 20% 소망 이뤄줄까[종합]",
#  '[HD영상] \'어비스\' 안효섭 "\'세젤흔녀\' 박보영? 얼굴 보면 몰입 안 된다"',
#  '“흔녀된 뽀블리”…박보영X유제원 감독, ‘오나귀’ 잇는 신드롬 일으킬까(종...',
#  '박보영 이런 모습도 있네요?',
#  '2019.04.29 박보영 쏘피 바디피트 팬사인회 현장',
#  '박보영은 언제쯤 결혼을 할까요?',
#  '박보영 나오는 드라마 하나봐요',
#  '럭키슈에뜨 박보영 가디건',
#  '박보영 : 오 나의 귀신님 나봉선',
#  '[티저] 초면에 사랑합니다 vs 어비스 (김영광vs박보영)',
#  '월화드라마 어비스로 돌아올 박보영 스타일에 대해 알아보자',
#  '박보영 김영광 열애 나이와키 군대 미우새 출연',
#  '박보영 김영광 열애 키차이 아버지 군대 ?',
#  '박보영',
#  '연지해',
#  'Park Bo-young',
#  '박보영 - 나무위키',
#  '박보영 갤러리',
#  '박보영']

# %%
html = download("https://search.daum.net/search",{"q":"박보영"})
daum = BeautifulSoup(html.text,"lxml")

# %%
daum
# Out:
# <!DOCTYPE html>
# <html class="win ie11" lang="ko" xmlns="http://www.w3.org/1999/xhtml">
# <head profile="http://a9.com/-/spec/opensearch/1.1/">
# <meta content="text/html;charset=utf-8" http-equiv="content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="off" name="autocomplete"/>
# <meta content="always" name="referrer"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="박보영 – Daum 검색" property="og:title"/>
# <meta content="https://search.daum.net/search?w=tot&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81" property="og:url"/>
# <meta content="Daum 검색에서 박보영에 대한 최신정보를 찾아보세요." property="og:description"/>
# <meta content="https://search1.daumcdn.net/search/statics/common/img/og_search.png" property="og:image"/>
# <meta content="다음검색" property="og:site_name"/>
# <title>박보영 – Daum 검색</title>
# <link href="//search.daum.net/OpenSearch.xml" rel="search" title="Daum" type="application/opensearchdescription+xml"/>
# <link charset="utf-8" href="//search1.daumcdn.net/search/statics/common/css/2019/p_common.0423051504.css" rel="stylesheet" type="text/css"/>
# <link charset="utf-8" href="//search1.daumcdn.net/search/statics/common/css/2019/p_collection.0423051504.css" rel="stylesheet" type="text/css"/>
# <link charset="utf-8" href="//search1.daumcdn.net/search/statics/common/css/2019/p_collection2.0423051504.css" rel="stylesheet" type="text/css"/>
# <link charset="utf-8" href="//search1.daumcdn.net/search/statics/common/css/2018/poiColl.0306042122.css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
# var SF, C, T;
# var uk = "XMw@TNPnaU4AACnuZpUAAABz";
# var mk = "XMw@TNPnaU4AACnuZpUAAABz";
# var ud = "";
# var uuid = "";
# var adid = "";
# var adid_enabled = "N";
# var viewio = "i";
# var viewsite = "";
# var ServerTime = "20190503221244";
# var EnQuery = "%B9%DA%BA%B8%BF%B5";
# var utf8Query = "%EB%B0%95%EB%B3%B4%EC%98%81";
# var topQuery = "박보영";
# var backQuery = "%EB%B0%95%EB%B3%B4%EC%98%81";
# var login_yn = "N";
# var encodeType = "2";
# var refCode = "";
# var bucketType = "";
# var name_check = "0";
# var mobileDevice = "N";
# var param_w="tot";
# var param_da = "";
# var paramCfg = "";
# var param_cnucc = "";
# var cnucc = "";
# var usrIp = "115.91.55.67";
# var isDetailTab = "N";
# var width_over_620 = "N";
#
# var isReleaseMode = "";
#
# var KAKAO_ACCOUNT_ID_CONNECTED = "N";
#
# var displayInfo = {"SER":[{"code":"PRF","doc_count":4},{"code":"NNS","doc_count":6},{"code":"IIM","doc_count":20},{"code":"BR1","doc_count":4},{"code":"CCB","doc_count":4},{"code":"1DV","doc_count":2},{"code":"GG2","doc_count":4},{"code":"BRC","doc_count":3},{"code":"IVR","doc_count":4},{"code":"VO2","doc_count":5},{"code":"NKS","doc_count":4},{"code":"CLO","doc_count":5}],"SGR":[{"code":"NSJ","doc_count":0},{"code":"DCC","doc_count":0},{"code":"1TH","doc_count":0},{"code":"EOA","doc_count":0},{"code":"DRU","doc_count":0},{"code":"MBK","doc_count":0},{"code":"RSJ","doc_count":0}],"SUI":[]}
# ;
# var slCallType = "sync";
# var pageLoadedTime = 0;
# var startTime = new Date().getTime();
# var sugLocCode = "";
# var searchLog = {
# uc: 0,
# clickCount: 0,
# dl: ""
# };
# var SEARCHLOGDOMAIN = "//sl.search.daum.net";
# </script>
# <script id="answer-world-weather-template" type="text/html">
# <span class="weather_comp">
# <span class="txt_exact ico_suggest" data-bind="css: icon40">
# <span class="tit" data-bind="text: (country + ' ' + city)"></span>
# <span class="cont">
# <span class="txt_cont" data-bind="text: wtext"></span>
# <span class="txt_num1 ico_suggest2 ico_celsius txt_blue" data-bind="text: mintemp"></span><span class="txt_unit">℃</span>
# <span class="bar"> / </span>
# <span class="txt_num1 ico_suggest2 ico_celsius txt_red" data-bind="text: maxtemp"></span><span class="txt_unit">℃</span>
# </span>
# </span>
# <span class="txt_time" data-bind="text: (ddate + ', 한국기준')"></span>
# </span>
# </script>
# <script id="answer-korea-weather-template" type="text/html">
# <span class="weather_comp">
# <span class="txt_exact ico_suggest" data-bind="css: icon40">
# <span class="tit" data-bind="text: areaname"></span>
# <span class="cont"><span class="txt_cont" data-bind="text: wtext5s"></span> <span class="txt_num1 ico_suggest2 ico_celsius" data-bind="text: temp"></span><span class="txt_unit">℃</span></span>
# </span>
# <span class="txt_time" data-bind="text: (announce + ' 기준') "></span>
# </span>
# </script>
# <script charset="utf-8" src="//search1.daumcdn.net/search/statics/common/js/fe/tot-search/polyfill/p/polyfill.p.common.20190419133725.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="//search1.daumcdn.net/search/statics/common/js/fe/tot-search/vendor/p/common/vendor.p.common.20190423132502.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="//search1.daumcdn.net/search/statics/common/js/2019/p_log.min.20190430131236.js" type="text/javascript"></script>
# <script charset="utf-8" src="//search1.daumcdn.net/search/statics/common/js/fe/tot-search/module/p/common/module.p.common.20190430144329.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="//search1.daumcdn.net/search/statics/common/js/fe/tot-search/module/p/search/module.p.search.20190321202307.min.js" type="text/javascript"></script>
# <script>
# (function(SF, $, SL) {
# Object.assign(SF, {
# logStaticErrors: {
# isArgonUrl: function(url) {
# return url.indexOf('argon') !== -1;
# },
# extractArgonId: function(url) {
# return url.split('/').pop();
# },
# createFreeLogParams: function(ids) {
# return {
# timg: ids.join(',')
# };
# },
# chunkCall: function (fn, options) {
# var chunk = [];
# var debounced = $.debounce(function() {
# if (chunk.length > 0) {
# fn(chunk);
# chunk = [];
# }
# }, options.timeout);
# return function (arg) {
# chunk.push(arg);
# if (chunk.length >= options.chunkSize) {
# fn(chunk);
# chunk = [];
# }
# debounced();
# };
# },
# init: function() {
# this.subscribe();
# },
# subscribe: function() {
# var sendLog = this.chunkCall(this.sendLog.bind(this), {
# timeout: 1000,
# chunkSize: 50
# });
# var onError = this.onError.bind(this, sendLog);
# this.unsubscribe = function () {
# window.removeEventListener('error', onError);
# };
# window.addEventListener('error', onError, true);
# },
# onError: function (callback, event) {
# var src = event.target.src;
# if (typeof src === 'string' && this.isArgonUrl(src)) {
# callback(this.extractArgonId(src));
# }
# },
# sendLog: function(argonIds) {
# var params = this.createFreeLogParams(argonIds);
# SL.freelog.send(params);
# },
# unsubscribe: $.noop
# }
# });
# })(window.SF || {}, window.jQuery, window.SL || {});
# SF.logStaticErrors.init();
# </script>
# <script type="text/javascript">
# SF.loadModuleList = {
# "amcharts":"//search1.daumcdn.net/search/statics/common/js/fe/tot-search/library/p/amcharts.20190321202015.min.js",
# "kakaosdk":"//search1.daumcdn.net/search/statics/common/js/fe/tot-search/library/p/kakaosdk.20190321202015.min.js",
# "kakaotv":"//tv.kakao.com/player/script/sdk/player_api.min.js",
# "pagenavigation":"//search1.daumcdn.net/search/statics/common/js/fe/tot-search/module/p/pagenavigation/module.p.pagenavigation.20190423161542.min.js",
# "youtube":"//www.youtube.com/player_api"
# };
# </script>
# <script id="pagingTemplate" type="text/template">
# <span class="paging_inner">
# <% if(ePage<=1){ %>
# <br/><br/>
# <% } else { %>
# <% if(cPage>1){ %>
# <a href="<%=prevLink%>" class="ico_comm1 btn_page btn_prev" onclick='<%=log({rc:"", p:"", e:1, r:""})%>'>이전</a>
# <% } else { %>
# <span class="btn_page btn_prev">이전</span>
# <% } %>
# <% for(var i=sPage, j=0; i<=ePage; i++, j++){ %>
# <% if(i==cPage){ %>
# <span class="screen_out">현재페이지</span><em class="btn_page"><%=i%></em>
# <% } else { %>
# <a href="<%=linksArr[j]%>" class="btn_page" onclick='<%=log({p:1, r:i, rc:(ePage-sPage+1), e:""})%>'><%=i%></a>
# <% } %>
# <% } %>
# <% if(totPage>cPage){ %>
# <a href="<%=nextLink%>" class="ico_comm1 btn_page btn_next" onclick='<%=log({rc:"", p:"", e:2, r:""})%>'><em>다음</em></a>
# <% } else { %>
# <span class="btn_page btn_next">다음</span>
# <% } %>
# <% } %>
# </span>
# </script>
# <!--[if IE]>
# <script src="//search1.daumcdn.net/search/statics/common/js/g/html5.min.js"></script>
# <![endif]-->
# </head>
# <body class="daum netizen_btm">
# <script type="text/javascript">
# SL.mkeyLog();
# </script>
# <nav class="d_direct" id="daumIndex">
# <a class="link_direct" href="#daumBody">본문 바로가기</a>
# <a class="link_direct" href="#daumGnb">메뉴 바로가기</a>
# <a class="link_direct" href="#realtimeIssueTitle">실시간이슈 바로가기</a>
# </nav>
# <div id="tooltipContent"></div> <!-- TT -->
# <div id="saq" style="display:none">박보영</div>
# <article class="daum_wrap" id="daumWrap">
# <header id="daumHead">
# <div class="inner_header" id="innerHeader">
# <h1>
# <a href="https://www.daum.net/?nil_profile=daum&amp;nil_src=search" id="daumLogo" onclick='smartLog(this, "e=1&amp;dc=MLC", event);' target="_top" title="Daum 메인페이지로 가기">
# <img alt="Daum" height="34" src="//search1.daumcdn.net/search/statics/common/pi/logo/daumlogo_170324.png" width="84"/>
# </a>
# <span class="screen_out" id="daumServiceLogo">검색</span>
# </h1>
# <form class="d_sch" id="daumSearch" method="get" name="search" onsubmit="check_submit(event); return false;">
# <fieldset class="fld_total">
# <legend class="screen_out">검색폼</legend>
# <input id="nil_suggest" name="nil_suggest" type="hidden" value="btn"/>
# <input id="nil_ch" name="nil_ch" type="hidden" value=""/>
# <input name="rtupcoll" type="hidden" value=""/>
# <input name="w" type="hidden" value="tot"/>
# <input name="m" type="hidden" value=""/>
# <input id="f" name="f" type="hidden" value=""/>
# <input name="lpp" type="hidden" value=""/>
# <input name="DA" type="hidden" value="SBC"/>
# <input name="sug" type="hidden" value=""/>
# <input name="sq" type="hidden" value=""/>
# <input name="o" type="hidden" value=""/>
# <input name="sugo" type="hidden" value=""/>
# <div class="box_searchbar">
# <div class="inner_searchbar">
# <input autocomplete="off" class="tf_keyword" id="q" maxlength="255" name="q" spellcheck="false" title="검색어 입력" type="text" value="박보영"/>
# <button class="img_keyboard btn_key" id="VKIBtn" onclick="SF.virtualKeyboardHandler.call();smartLog(this, 'pg=1&amp;p=1&amp;r=1&amp;rc=1&amp;dc=BFJ&amp;at=func',event);return false;" type="button"><span class="ir_wa">한글입력기</span></button>
# <button class="ico_ksearch btn_ksearch" id="daumBtnSearch" type="submit"><span class="ir_wa">검색</span></button>
# </div>
# </div>
# <div class="wrap_suggestBox" id="wrap_suggestBox"><div class="suggestBox box_sub" id="suggestBox"></div></div>
# </fieldset>
# </form>
# <script type="text/javascript">
# (function() {
# jQuery("#f").val("");
# var searchInp = jQuery("#q");
# var boxSearch = jQuery("#daumSearch .box_searchbar");
# searchInp.on("focus", function() {
# boxSearch.addClass("search_on");
# });
# searchInp.on("blur", function() {
# boxSearch.removeClass("search_on");
# });
# })();
# </script>
# <div id="wrapMinidaum"></div>
# <div class="keyboard_layer" id="VKILayout" style="display:none;"></div>
# <div class="cl_b"></div>
# </div>
# <div id="daumGnb">
# <div class="wrap_gnb">
# <ul class="gnb_search">
# <li class="on">
# <span class="screen_out">선택된 항목</span>
# <a class="tab tab_total" href="?w=tot&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NTB" onclick='smartLog(this, "pg=1&amp;r=1&amp;p=1&amp;rc=1&amp;dc=NTB&amp;at=more", event);'><span class="inner_tab"><span class="txt_tab">통합검색</span></span></a>
# </li>
# <li class="">
# <a class="tab tab_news" href="?w=news&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;cluster=y&amp;cluster_page=1&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81" onclick='smartLog(this, "pg=1&amp;r=2&amp;p=1&amp;rc=1&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">뉴스</span></span>
# </a>
# </li>
# <li class="">
# <a class="tab tab_img" href="?w=img&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81" onclick='smartLog(this, "pg=1&amp;r=3&amp;p=1&amp;rc=1&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">이미지</span></span>
# </a>
# </li>
# <li class="">
# <a class="tab tab_blog" href="?w=blog&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81" onclick='smartLog(this, "pg=1&amp;r=4&amp;p=1&amp;rc=1&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">블로그</span></span>
# </a>
# </li>
# <li class="">
# <a class="tab tab_cafe" href="?w=cafe&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;ASearchType=1&amp;lpp=10&amp;rlang=0&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81" onclick='smartLog(this, "pg=1&amp;r=5&amp;p=1&amp;rc=1&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">카페</span></span>
# </a>
# </li>
# <li class="">
# <a class="tab tab_dic100" href="http://100.daum.net/search/entry?q=%EB%B0%95%EB%B3%B4%EC%98%81" onclick='smartLog(this, "pg=1&amp;r=6&amp;p=1&amp;rc=1&amp;dc=NTB&amp;at=more", event);' target="_blank">
# <span class="inner_tab">
# <span class="txt_tab">백과사전</span>
# <span class="ico_ksearch ico_outlink">새창</span>
# </span>
# </a>
# </li>
# <li class="">
# <a class="tab tab_map" href="http://map.daum.net/?from=total&amp;nil_suggest=btn&amp;tab=place&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81" onclick='smartLog(this, "pg=1&amp;r=7&amp;p=1&amp;rc=1&amp;dc=NTB&amp;at=more", event);' target="_blank">
# <span class="inner_tab">
# <span class="txt_tab">지도</span>
# <span class="ico_ksearch ico_outlink">새창</span>
# </span>
# </a>
# </li>
# <li class="">
# <a class="tab tab_site" href="?w=site&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;lpp=10&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81" onclick='smartLog(this, "pg=1&amp;r=8&amp;p=1&amp;rc=1&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">사이트</span></span>
# </a>
# </li>
# </ul>
# <div class="more_search">
# <a class="btn_tab" href="javascript:;" id="gnbToggleBtn">
# <span class="txt_btn">더보기/접기</span>
# </a>
# <ul class="list_more">
# <li class="">
# <a class="link_more tab_vclip" href="?w=vclip&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81" onclick='smartLog(this, "pg=1&amp;r=9&amp;p=2&amp;rc=1&amp;e1=TO&amp;e2=VO2Z&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">동영상</span></span>
# </a>
# </li>
# <li class="">
# <a class="link_more tab_knowledge" href="?w=knowledge&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81" onclick='smartLog(this, "pg=1&amp;r=10&amp;p=2&amp;rc=1&amp;e1=TO&amp;e2=NKSZ&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">팁</span></span>
# </a>
# </li>
# <li class="">
# <a class="link_more tab_social" href="?w=social&amp;m=web&amp;sort_type=socialweb&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81" onclick='smartLog(this, "pg=1&amp;r=11&amp;p=2&amp;rc=1&amp;e1=TO&amp;e2=FGKZ&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">트위터</span></span>
# </a>
# </li>
# <li class="">
# <a class="link_more tab_webdoc" href="?w=web&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;lpp=10&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81" onclick='smartLog(this, "pg=1&amp;r=12&amp;p=2&amp;rc=1&amp;e1=TO&amp;e2=WSAZ&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">웹문서</span></span>
# </a>
# </li>
# <li class="">
# <a class="link_more tab_dic" href="http://dic.daum.net/search.do?q=%EB%B0%95%EB%B3%B4%EC%98%81" onclick='smartLog(this, "pg=1&amp;r=13&amp;p=2&amp;rc=1&amp;e1=TO&amp;e2=DICZ&amp;dc=NTB&amp;at=more", event);' target="_blank">
# <span class="inner_tab">
# <span class="txt_tab">어학사전</span>
# <span class="ico_ksearch ico_outlink">새창</span>
# </span>
# </a>
# </li>
# <li class="">
# <a class="link_more tab_shop" href="http://shopping.daum.net/in/search?srchhow=Cexpo&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81" onclick='smartLog(this, "pg=1&amp;r=14&amp;p=2&amp;rc=1&amp;e1=TO&amp;e2=SNPZ&amp;dc=NTB&amp;at=more", event);' target="_blank">
# <span class="inner_tab">
# <span class="txt_tab">쇼핑</span>
# <span class="ico_ksearch ico_outlink">새창</span>
# </span>
# </a>
# </li>
# <li class="">
# <a class="link_more tab_book" href="?w=book&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81" onclick='smartLog(this, "pg=1&amp;r=15&amp;p=2&amp;rc=1&amp;e1=TO&amp;e2=LB0Z&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">책</span></span>
# </a>
# </li>
# <li class="">
# <a class="link_more tab_music" href="?w=music&amp;m=song&amp;nil_search=btn&amp;DA=NTB&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81" onclick='smartLog(this, "pg=1&amp;r=16&amp;p=2&amp;rc=1&amp;e1=TO&amp;e2=MS2Z&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">멜론뮤직</span></span>
# </a>
# </li>
# </ul>
# </div>
# <div class="select_comp_d" id="commonSoWrapper">
# <div class="btn_flex btn_selected" data-so-label="period">
# <span class="inner">
# <span class="txt_data">기간전체</span>
# <span class="ico_tabopt ico_arr"></span>
# </span>
# </div>
# <div class="layer_opt" data-so-wrapper="period">
# <ul class="list_opt">
# <li class="on">
# <a class="tit_item" data-so-param="period=" href="javascript:;" onclick='smartLog(this, "pg=1&amp;r=1&amp;p=1&amp;dc=STC&amp;at=func", event);'>
# <span class="txt_data">기간전체</span>
# </a>
# </li>
# <li>
# <a class="tit_item" data-so-param="period=d" href="javascript:;" onclick='smartLog(this, "pg=1&amp;r=1&amp;p=2&amp;dc=STC&amp;at=func", event);'>
# <span class="txt_data">최근 1일</span>
# </a>
# </li>
# <li>
# <a class="tit_item" data-so-param="period=w" href="javascript:;" onclick='smartLog(this, "pg=1&amp;r=1&amp;p=3&amp;dc=STC&amp;at=func", event);'>
# <span class="txt_data">최근 1주</span>
# </a>
# </li>
# <li>
# <a class="tit_item" data-so-param="period=m" href="javascript:;" onclick='smartLog(this, "pg=1&amp;r=1&amp;p=4&amp;dc=STC&amp;at=func", event);'>
# <span class="txt_data">최근 1개월</span>
# </a>
# </li>
# <li>
# <a class="tit_item" data-so-param="period=6m" href="javascript:;" onclick='smartLog(this, "pg=1&amp;r=1&amp;p=5&amp;dc=STC&amp;at=func", event);'>
# <span class="txt_data">최근 6개월</span>
# </a>
# </li>
# <li>
# <a class="tit_item" data-so-param="period=y" href="javascript:;" onclick='smartLog(this, "pg=1&amp;r=1&amp;p=6&amp;dc=STC&amp;at=func", event);'>
# <span class="txt_data">최근 1년</span>
# </a>
# </li>
# </ul>
# <div class="box_sub box_date">
# <strong class="tit_other">직접입력</strong>
# <div class="item_date">
# <input class="tf_txt" data-so-param="period=u" title="검색기간 시작일" type="text" value="2017.04.03"/>
# <a class="btn_date" href="javascript:;"><img alt="Select date" class="ui-datepicker-trigger" src="//search1.daumcdn.net/search/statics/common/pi/ico/ico_calendar.gif" title="Select date"/>
# </a>
# </div>
# <div class="item_date">
# <input class="tf_txt" data-so-param="period=u" title="검색기간 종료일" type="text"/>
# <a class="btn_date" href="javascript:;"><img alt="Select date" class="ui-datepicker-trigger" src="//search1.daumcdn.net/search/statics/common/pi/ico/ico_calendar.gif" title="Select date"/>
# </a>
# </div>
# <button class="btn_confirm" type="submit">적용</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#
# _jsSetCookieNonEscape = function(name,value){
# document.cookie = name+"="+value+"; path=/;";
# };
# _jsSetCookieNonEscape("ODT", "");
# _jsSetCookieNonEscape("DDT", "");
# _jsSetCookieNonEscape("DTQUERY", "%EB%B0%95%EB%B3%B4%EC%98%81" );
#
#
# jq(document).on('ready', function(){
# var searchOption = new SF.searchOption({
# container : jq('#commonSoWrapper'),
# uiType : 'select'
# });
# });
#
# </script>
# <form method="get" name="cUccForm">
# <input name="kword" type="hidden"/>
# <input name="colid" type="hidden"/>
# <input name="docid" type="hidden"/>
# <input name="backurl" type="hidden"/>
# </form>
# <form method="get" name="urForm">
# <input name="q" type="hidden"/>
# </form>
# <div class="clr"></div>
# <!-- // daumGnb -->
# <div class="skiptonavi" id="searchData" name="searchData"></div>
# <!-- End Header -->
# </header>
# <script id="suggest-footer-template" type="text/html">
# <div>
# <span>
# <div class="fr">
# <a href="http://cs.daum.net/faq/15/14957.html#28978" class="isSuggest" target="_blank" onclick="smartLog(this, 'dc=SUG&p=5&r=1', event);">서제스트란?</a>
# </div>
# </span>
# </div>
# </script>
# <script type="text/javascript">
# var suggestInstance = new suggest.Suggest(document.getElementById('innerHeader'), {
# inputEl: 'q',
# suggestBoxEl: 'suggestBox',
# searchButtonEl: 'daumBtnSearch',
# type: 'DEFAULT',
# autoFocus: 'WRITE',
# suggestLimit: 15,
# recentLimit: 15,
# isReverse: false,
# searchURL: '',
# AnswerAPIServer: 'https://ninstant.search.daum.net/suggest/index.daum',
# enableRecentList: false,
# enableFooter: true
# });
# suggestInstance.on('click-item', function (event) {
# var f = document.search;
# var clickedItemInfo = suggestInstance.getActiveItem();
# var data = clickedItemInfo.data;
# var index = clickedItemInfo.index;
# var type = clickedItemInfo.type;
# f.sug.value = "";
# f.DA.value = "";
# f.nil_suggest.value = "";
# var sgtq = null;
# var sn = null;
# var _ci = function() {
# return document.createElement('input');
# };
# if (clickedItemInfo.type === 'ANSWER') {
# f.sug.value = "totex";
# f.DA.value = "EKS";
# f.nil_suggest.value = "sugsch";
# } else {
# if (data) {
# sgtq = suggestInstance.getUserEnteredQuery();
# sn = index > -1 ? index + 1 : '';
# if (sgtq != null && sgtq != "" ) {
# if (sgtq != null && sgtq != "" && sn != null && sn != "") {
# f.sq.value = sgtq;
# f.o.value = sn;
# f.sugo.value = suggestInstance.getSuggestions().length;
# }
# }
# if (type && type === 'RECENT') {
# f.DA.value = "FFV";
# if (!f.nil_profile) {
# var input = document.createElement('input');
# input.type = 'hidden';
# input.name = 'nil_profile';
# f.appendChild(input);
# } else {
# f.nil_profile.value = '';
# }
# f.nil_profile.value = "reckwd";
# } else {
# f.DA.value = "GIQ";
# f.nil_suggest.value = "sugsch";
# }
# } else {
# f.nil_suggest.value = "btn";
# f.DA.value = "SBC";
# }
# }
# check_submit(event,document.search);
# });
# daum.suggest = window.rudolph || {};
# </script>
# <article id="daumContent">
# <div id="cMain">
# <script type="text/javascript">
# searchLog.dl = 'NSJ0_PRF4_NNS6_IIM8_BR14_CCB4_1DV2_GG24_BRC3_IVR4_VO25_NKS4_DCC0_1TH0_EOA0_DRU0_MBK0_RSJ0_CLO5';	/* ISM DISPLAY_RESULT */
# var smDisCode = "";
# var smClickCode = "";
# var smCateCode = "";
# var totCollCount = "11";
# var sPageLoadedmsTime = 62;
# var requestTime = "1556889164308";
# </script>
# <article id="mArticle">
# <div class="inner_article">
# <span class="screen_out" id="daumBody">검색 본문</span>
# <div class="g_comp" disp-attr="NSJ" style="position: relative;">
# <script type="text/javascript">
# /**
# * 관련검색어 pc용 스크립트
# * 바로가기 니즈 키워드 (기준 CTR 50% 이상) 인 경우 관련검색어 노출을 확대해서(3줄 펼치기 형태) 관련검색어 클릭을 높인다 - 2013.11.5 로직 삭제
# */
# (function (jq) {
# C.netizenColl = C.netizenColl || {};
# C.netizenColl = {
# applyTopBottom: function (position) {
# var NetizenToggle = function (type) {
# this.type = (type) ? type : "";
# this.btnEl = jq("#netizen_more_btn_" + type);
# this.btnTextEl = jq("#netizen_more_btn_" + type + " span.ico_rwd");
# this.listsWrapper = jq("#netizen_lists_" + this.type);
# this.lists = jq("#netizenColl_" + this.type + " .list_keyword span.wsn");
# this.listKeywords = jq("#netizenColl_" + this.type + " .list_keyword span.wsn a.keyword");
# this.tab = this.listsWrapper.data("w");
# this.listFoldClass = (this.tab == "img") ? "type1" : "type2";   /* 이미지는 기본 1줄, 나머지는 기본 2줄 노출 */
# this.listOpenClass = "type3";   /* 쵀대 4줄 노출 */
# };
# NetizenToggle.prototype = {
# init: function () {
# if (this.btnEl.length > 0) {
# this.setListType();
# this.btnEl.unbind("click").bind("click", jq.proxy(this.toggle, this));
# this.listKeywords.unbind("click").bind("click", jq.proxy(this.sendLog, this));
# jq(window).resize(jq.proxy(this.setListType, this));
# }
# },
# setListType: function () {
# var lineCount = this.getLineCount();
# switch (lineCount) {
# case 1:
# this.setBtnStatus("more", "hide");
# this.listsWrapper[0].className = "list_keyword";
# break;
# case 2:
# if (this.tab == "img") {
# if (this.listsWrapper.hasClass("type3")) {
# this.setBtnStatus("fold", "show");
# this.listsWrapper[0].className = "list_keyword " + this.listOpenClass;
# } else {
# this.setBtnStatus("more", "show");
# this.listsWrapper[0].className = "list_keyword " + this.listFoldClass;
# }
# } else {
# this.setBtnStatus("more", "hide");
# this.listsWrapper[0].className = "list_keyword";
# }
# break;
# case 3:
# case 4:
# if (this.tab == "img") {
# if (this.listsWrapper.hasClass("type1") || this.listsWrapper.hasClass("type2")) {
# this.setBtnStatus("more", "show");
# this.listsWrapper[0].className = "list_keyword " + this.listFoldClass;
# } else {
# this.listsWrapper[0].className = "list_keyword " + this.listOpenClass;
# }
# } else {
# this.setBtnStatus("more", "show");
# this.listsWrapper[0].className = "list_keyword " + this.listFoldClass;
# }
# break;
# }
# },
# setBtnStatus: function (opt1, opt2) {
# if (opt1 == "more") {
# this.btnEl.removeClass("fold");
# this.btnTextEl.text('더보기');
# } else if (opt1 == "fold") {
# this.btnEl.addClass("fold");
# this.btnTextEl.text('접기');
# }
# if (typeof(opt2) != "undefined") {
# if (opt2 == "hide") {
# jq(this.btnEl).addClass("hide");
# } else if (opt2 == "show") {
# jq(this.btnEl).removeClass("hide");
# }
# }
# },
# toggle: function (e) {
# var lineCount = this.getLineCount();
# var logData = this.btnEl.data("log");
# if (lineCount > 1) {
# if (this.btnEl.length > 0) {
# if (this.btnEl.hasClass("fold")) {
# this.setBtnStatus("more");
# this.listsWrapper[0].className = "list_keyword " + this.listFoldClass;
# smartLog(this.btnEl, logData + "&e=2", e);
# } else {
# this.setBtnStatus("fold");
# this.listsWrapper[0].className = "list_keyword " + this.listOpenClass;
# smartLog(this.btnEl, logData + "&e=1", e);
# }
# }
# }
# },
# getLineCount: function () {
# var list = this.lists[this.lists.length - 1];
# var top = jq(list).position().top;
# var lineHeight = 25;
# var margin = 5;
# /* 한 줄이 25 */
# if (top >= lineHeight * 3 && top >= lineHeight * 3 - margin) {  /* 70~75 */
# return 4;
# } else if (top >= lineHeight * 2 && top >= lineHeight * 2 - margin) { /* 45~50 */
# return 3;
# } else if (top >= lineHeight && top >= lineHeight - margin) {    /* 20~25 */
# return 2;
# } else {    /* ~20 */
# return 1;
# }
# },
# sendLog: function (e) {
# e.stopPropagation();
# var target = function () {
# if (e.target.tagName.toLowerCase() == "span") {
# return e.target.firstChild;
# } else if (e.target.tagName.toLowerCase() == "a") {
# return e.target;
# }
# }();
# var log = jq(target).data("log");
# var extra = {
# "relkwd": {
# "click_query": jq(target).text()
# }
# };
# smartLog(target, log, e, extra);
# }
# };
# var netizenToggle;
# netizenToggle = new NetizenToggle(position);
# netizenToggle.init();
# /* 이미지 탭에서 상단 관련검색어 미들 top 사이즈 체크할 때, 렌더링 타이밍 이슈로 넣어 둠. */
# setTimeout(function () {
# netizenToggle.setListType();
# }, 0);
# },
# applyRight: function () {
# /* ie6, ie7, ipad 가 아니면 */
# if (!((SF.ua.browser.name == "msie" && (SF.ua.browser.version.major == "6" || SF.ua.browser.version.major == "7")) || (SF.ua.browser.name == "ipad"))) {
# this.fixTop();
# }
# var listKeywords = jq("#netizenColl_right .list_keyword a.link_txt");
# listKeywords.unbind("click").bind("click", jq.proxy(this.sendLog, this));
# },
# sendLog: function (e) {
# e.stopPropagation();
# var target = function () {
# if (e.target.tagName.toLowerCase() == "span") {
# return e.target.parentNode;
# } else if (e.target.tagName.toLowerCase() == "a") {
# return e.target;
# }
# }();
# var log = jq(target).data("log");
# var freeLog = {
# "relkwd": {
# "click_query": jq(target).text()
# }
# };
# smartLog(target, log, e, freeLog);
# },
# fixTop: function () {
# var netizenEl = jq("#netizenColl_right")[0];
# if (netizenEl) {
# var bodyHeight = jq("#daumWrap")[0].clientHeight;
# if (viewsite == "0001L") {
# /* SA일경우 */
# var headerHeight = jq("#bingHead")[0].clientHeight;
# var footerHeight = jq("#bingFoot")[0].clientHeight;
# } else {
# var headerHeight = jq("#daumHead")[0].clientHeight;
# var footerHeight = jq("#daumFoot")[0].clientHeight;
# }
# var netizenHeight = netizenEl.clientHeight;
# var netizenTop = jq(netizenEl).position().top;
# var offset = 60;
# /* 우하단 맨위로 버튼으로 인한 오프셋  */
# var prevHeight = 0;
# var browserHeight = 0;
# var checkNetizen = function () {
# var isHorizontalScrollbar = document.documentElement.scrollWidth > document.documentElement.clientWidth;
# var scrollTop = getScrollOffsets().top;
# browserHeight = getWindowSize().height;
# var fixMode = ((scrollTop - headerHeight) >= netizenTop) ? true : false;
# if (isHorizontalScrollbar) {
# fixMode = false;
# }
# if (fixMode) {
# jq(netizenEl).addClass("netizen_fixed");
# if (scrollTop > (bodyHeight - (netizenHeight + footerHeight + offset))) {
# netizenEl.style.top = bodyHeight - (footerHeight + offset + netizenHeight) - scrollTop + "px";
# } else {
# netizenEl.style.top = "-1px";
# }
# } else {
# jq(netizenEl).removeClass("netizen_fixed");
# }
# };
# var getScrollOffsets = function () {
# return {
# 'left': window.pageXOffset || document.documentElement.scrollLeft || document.body.scrollLeft,
# 'top': window.pageYOffset || document.documentElement.scrollTop || document.body.scrollTop
# };
# };
# var getWindowSize = function () {
# var w = (window.innerWidth || document.documentElement.clientWidth || document.body.clientWidth || 1003) - 2,
# h = (window.innerHeight || document.documentElement.clientHeight || document.body.clientHeight || 650) - 2;
# return {"width": w, "height": h};
# };
# checkNetizen();
# jq(window).scroll(checkNetizen);
# jq(window).resize(function () {
# /* 브라우저 리사이즈시에는 높이가 달라졌을때는 클래스 순간 지움. (위치 새로 잡기위해) */
# if (prevHeight == browserHeight) {
# jq(netizenEl).removeClass("netizen_fixed");
# }
# checkNetizen();
# prevHeight = browserHeight;
# });
# }
# }
# };
# /**
# * pc 우측 박스용 말줄임
# */
# C.netizenColl.ellipsis = {
# FRONT_MARGIN: 0,
# ADDITIONAL_MARGIN: 15,
# /**
# 1. 25byte 이상인 서브키가 몇개인지 측정
# 2. 그 글자들과 메인키의 일치비율 측정 => 편집거리 사용.
# 2-1. 키워드와 똑같이 잘라서 편집거리 측정
# 3. 일치비율 >= 0.5 이상이면 중간말줄임, 아니면 기본 말줄임
# */
# draw: function () {
# var _this = this;
# var keyword = decodeURIComponent(utf8Query).replace(/\s/g, "");
# var longKeyword = this.getLongSubkey();
# if (longKeyword.length > 0) {
# var editDistances = jq.map(longKeyword, function (subkey) {
# /* 2-1 단계 */
# var cuttingSubkey = subkey.replace(/\s/g, "").substring(0, keyword.length);
# return _this.getEditDistance(_this.hangulToJaso(keyword), _this.hangulToJaso(cuttingSubkey));
# });
# var sumOfEditDistances = 0;
# jq.each(editDistances, function (index, value) {
# sumOfEditDistances += value;
# });
# var avgOfEditDistances = sumOfEditDistances / editDistances.length;
# var zeroCnt = jq.grep(editDistances, function (dist) {
# return dist <= avgOfEditDistances;
# }).length;
# var sumOfDiffSquare = 0;
# jq.each(editDistances, function (index, dist) {
# sumOfDiffSquare += Math.pow(dist - avgOfEditDistances, 2);
# });
# var matchRatio = zeroCnt / longKeyword.length;
# var variance = sumOfDiffSquare / editDistances.length;
# /* 일치비율이 0.5 이상이거나 0.3 이상이지만 분산이 2보다 작을때는 중간 말줄임 적용(프로그램명 n회 같은 쿼리는 일치비율이 작게 나오기 때문) */
# if (matchRatio >= 0.5 || (matchRatio >= 0.3 && variance < 2)) {
# this.setMiddleEllipsis();
# } else {
# this.setFullSubkey();
# }
# } else {
# this.setFullSubkey();
# }
# },
# /**
# * 25byte 이상인 키워드 몇개인지 측정
# */
# getLongSubkey: function () {
# var _this = this;
# return jq.map(jq("#netizenColl_right .txt_keyword"), function (elem, index) {
# var subkey = jq(elem).attr("data");
# if (_this.getByte(subkey) >= 25) {
# return subkey;
# }
# });
# },
# /**
# * 한글도 2byte로 계산하는 바이트 계산 함수
# */
# getByte: function (s, b, i, c) {
# for (b = i = 0; c = s.charCodeAt(i++); b += c >> 7 ? 2 : 1);
# return b;
# },
# /**
# * 한글 자소 분리
# * brunch B.Util.js 의 hangulToJaso 가져와서 사용.
# */
# hangulToJaso: function (text) {
# var ChoSeong = [0x3131, 0x3132, 0x3134, 0x3137, 0x3138,
# 0x3139, 0x3141, 0x3142, 0x3143, 0x3145, 0x3146, 0x3147, 0x3148,
# 0x3149, 0x314a, 0x314b, 0x314c, 0x314d, 0x314e];
# var JungSeong = [0x314f, 0x3150, 0x3151, 0x3152, 0x3153,
# 0x3154, 0x3155, 0x3156, 0x3157, 0x3158, 0x3159, 0x315a, 0x315b,
# 0x315c, 0x315d, 0x315e, 0x315f, 0x3160, 0x3161, 0x3162, 0x3163];
# var JongSeong = [0x0000, 0x3131, 0x3132, 0x3133, 0x3134,
# 0x3135, 0x3136, 0x3137, 0x3139, 0x313a, 0x313b, 0x313c, 0x313d,
# 0x313e, 0x313f, 0x3140, 0x3141, 0x3142, 0x3144, 0x3145, 0x3146,
# 0x3147, 0x3148, 0x314a, 0x314b, 0x314c, 0x314d, 0x314e];
# var chars = [];
# var v = [];
# for (var i = 0; i < text.length; i++) {
# chars[i] = text.charCodeAt(i);
# if (chars[i] >= 0xAC00 && chars[i] <= 0xD7A3) {
# var i1, i2, i3;
# i3 = chars[i] - 0xAC00;
# i1 = i3 / (21 * 28);
# i3 = i3 % (21 * 28);
# i2 = i3 / 28;
# i3 = i3 % 28;
# v.push(String.fromCharCode(ChoSeong[parseInt(i1)]));
# v.push(String.fromCharCode(JungSeong[parseInt(i2)]));
# if (i3 != 0x0000)
# v.push(String.fromCharCode(JongSeong[parseInt(i3)]));
# }
# else {
# v.push(String.fromCharCode(chars[i]));
# }
# }
# return v.join("");
# },
# /**
# * 편집거리 측정
# */
# getEditDistance: function (a, b) {
# if (a.length === 0) return b.length;
# if (b.length === 0) return a.length;
# var matrix = [];
# /* increment along the first column of each row */
# var i;
# for (i = 0; i <= b.length; i++) {
# matrix[i] = [i];
# }
# /* increment each column in the first row */
# var j;
# for (j = 0; j <= a.length; j++) {
# matrix[0][j] = j;
# }
# /* Fill in the rest of the matrix */
# for (i = 1; i <= b.length; i++) {
# for (j = 1; j <= a.length; j++) {
# if (b.charAt(i - 1) == a.charAt(j - 1)) {
# matrix[i][j] = matrix[i - 1][j - 1];
# } else {
# matrix[i][j] = Math.min(matrix[i - 1][j - 1] + 1, /* substitution */
# Math.min(matrix[i][j - 1] + 1, /* insertion */
# matrix[i - 1][j] + 1)); /* deletion */
# }
# }
# }
# return matrix[b.length][a.length];
# },
# /**
# * 중간 말줄임 적용
# */
# setMiddleEllipsis: function () {
# var width = 0;
# width = (jq("#netizenColl_right .list_keyword").width()) / 2;
# if (width <= 0) {
# this.setFullSubkey();
# return;
# }
# width = width - this.FRONT_MARGIN - this.ADDITIONAL_MARGIN;
# /* width 보다 넓으면 한글자씩 빼기 */
# jq.each(jq("#netizenColl_right .txt_keyword"), function (index, elem) {
# var subkey = jq(elem).attr("data");
# var len = subkey.length;
# jq(elem).text(subkey);
# var mid = len / 2;
# var removeLen = 2;
# var head, tail;
# while (jq(elem).width() > width) {
# head = subkey.substring(0, mid - removeLen / 2);
# tail = subkey.substring(mid + removeLen / 2, len);
# jq(elem).text(head + "..." + tail);
# removeLen++;
# }
# });
# },
# setFullSubkey: function () {
# jq.each(jq("#netizenColl_right .txt_keyword"), function (index, elem) {
# var subkey = jq(elem).attr("data");
# jq(elem).text(subkey);
# });
# }
# };
# jq(document).ready(function () {
# if (jq("#netizenColl_top").length > 0) {
# C.netizenColl.applyTopBottom("top");
# }
# if (jq("#netizenColl_bottom").length > 0) {
# C.netizenColl.applyTopBottom("bottom");
# }
# if (jq("#netizenColl_right").length > 0) {
# C.netizenColl.applyRight();
# C.netizenColl.ellipsis.draw();
# }
# });
# })(jQuery);
# </script>
# <div class="section_related" id="netizenColl_top">
# <div class="list_keyword type2" data-w="tot" id="netizen_lists_top">
# <h2 class="tit">
# 관련 <span class="screen_out">검색어</span>
# </h2>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;pg=1&amp;r=1&amp;p=1&amp;e1=%EB%B0%95%EB%B3%B4%EC%98%81%20%EB%AA%B8%EB%A7%A4&amp;rc=1" href="?w=tot&amp;m=&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81%20%EB%AA%B8%EB%A7%A4&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NSJ">박보영 몸매</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;pg=1&amp;r=2&amp;p=1&amp;e1=%EB%B0%95%EB%B3%B4%EC%98%81%20%EB%B9%84%ED%82%A4%EB%8B%88&amp;rc=1" href="?w=tot&amp;m=&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81%20%EB%B9%84%ED%82%A4%EB%8B%88&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NSJ">박보영 비키니</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;pg=1&amp;r=3&amp;p=1&amp;e1=%EB%B0%95%EB%B3%B4%EC%98%81%20%ED%82%A4&amp;rc=1" href="?w=tot&amp;m=&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81%20%ED%82%A4&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NSJ">박보영 키</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;pg=1&amp;r=4&amp;p=1&amp;e1=%EB%B0%95%EB%B3%B4%EC%98%81%20%EC%B6%9C%EC%97%B0%EB%A3%8C&amp;rc=1" href="?w=tot&amp;m=&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81%20%EC%B6%9C%EC%97%B0%EB%A3%8C&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NSJ">박보영 출연료</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;pg=1&amp;r=5&amp;p=1&amp;e1=%ED%95%9C%EC%A7%80%EB%AF%BC&amp;rc=1" href="?w=tot&amp;m=&amp;q=%ED%95%9C%EC%A7%80%EB%AF%BC&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NSJ">한지민</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;pg=1&amp;r=6&amp;p=1&amp;e1=%EC%95%88%ED%9A%A8%EC%84%AD&amp;rc=1" href="?w=tot&amp;m=&amp;q=%EC%95%88%ED%9A%A8%EC%84%AD&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NSJ">안효섭</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;pg=1&amp;r=7&amp;p=1&amp;e1=%EC%9D%B4%EB%B3%B4%EC%98%81&amp;rc=1" href="?w=tot&amp;m=&amp;q=%EC%9D%B4%EB%B3%B4%EC%98%81&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NSJ">이보영</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;pg=1&amp;r=8&amp;p=1&amp;e1=%EB%B0%95%EB%B3%B4%EC%98%81%20%EC%96%B4%EB%B9%84%EC%8A%A4&amp;rc=1" href="?w=tot&amp;m=&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81%20%EC%96%B4%EB%B9%84%EC%8A%A4&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NSJ">박보영 어비스</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;pg=1&amp;r=9&amp;p=1&amp;e1=%EC%86%90%EC%98%88%EC%A7%84&amp;rc=1" href="?w=tot&amp;m=&amp;q=%EC%86%90%EC%98%88%EC%A7%84&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NSJ">손예진</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;pg=1&amp;r=10&amp;p=1&amp;e1=%EB%B0%95%EB%B3%B4%EC%98%81%20%EC%8B%A4%EB%AC%BC&amp;rc=1" href="?w=tot&amp;m=&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81%20%EC%8B%A4%EB%AC%BC&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NSJ">박보영 실물</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;pg=1&amp;r=11&amp;p=1&amp;e1=%EA%B9%80%EC%98%81%EA%B4%91&amp;rc=1" href="?w=tot&amp;m=&amp;q=%EA%B9%80%EC%98%81%EA%B4%91&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NSJ">김영광</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;pg=1&amp;r=12&amp;p=1&amp;e1=%EA%B9%80%EC%A7%80%EC%9B%90&amp;rc=1" href="?w=tot&amp;m=&amp;q=%EA%B9%80%EC%A7%80%EC%9B%90&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NSJ">김지원</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;pg=1&amp;r=13&amp;p=1&amp;e1=%EB%B0%95%EB%AF%BC%EC%98%81&amp;rc=1" href="?w=tot&amp;m=&amp;q=%EB%B0%95%EB%AF%BC%EC%98%81&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NSJ">박민영</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;pg=1&amp;r=14&amp;p=1&amp;e1=%EB%B0%95%ED%98%95%EC%8B%9D&amp;rc=1" href="?w=tot&amp;m=&amp;q=%EB%B0%95%ED%98%95%EC%8B%9D&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NSJ">박형식</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;pg=1&amp;r=15&amp;p=1&amp;e1=%EB%B0%95%EB%B3%B4%EC%98%81%20%EB%8C%80%EB%B2%95%EA%B4%80&amp;rc=1" href="?w=tot&amp;m=&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81%20%EB%8C%80%EB%B2%95%EA%B4%80&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NSJ">박보영 대법관</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;pg=1&amp;r=16&amp;p=1&amp;e1=%EC%9E%A5%EB%82%98%EB%9D%BC&amp;rc=1" href="?w=tot&amp;m=&amp;q=%EC%9E%A5%EB%82%98%EB%9D%BC&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NSJ">장나라</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;pg=1&amp;r=17&amp;p=1&amp;e1=%EB%B0%95%EB%B3%B4%EC%98%81%20%EB%B0%95%ED%98%95%EC%8B%9D&amp;rc=1" href="?w=tot&amp;m=&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81%20%EB%B0%95%ED%98%95%EC%8B%9D&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NSJ">박보영 박형식</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;pg=1&amp;r=18&amp;p=1&amp;e1=%EC%95%84%EC%9D%B4%EB%A6%B0&amp;rc=1" href="?w=tot&amp;m=&amp;q=%EC%95%84%EC%9D%B4%EB%A6%B0&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NSJ">아이린</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;pg=1&amp;r=19&amp;p=1&amp;e1=%EA%B9%80%EC%9C%A0%EC%A0%95&amp;rc=1" href="?w=tot&amp;m=&amp;q=%EA%B9%80%EC%9C%A0%EC%A0%95&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NSJ">김유정</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;pg=1&amp;r=20&amp;p=1&amp;e1=%EB%B0%95%EB%B3%B4%EA%B2%80&amp;rc=1" href="?w=tot&amp;m=&amp;q=%EB%B0%95%EB%B3%B4%EA%B2%80&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NSJ">박보검</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;pg=1&amp;r=21&amp;p=1&amp;e1=%EB%B0%95%EB%B3%B4%EC%98%81%20%EC%96%BC%EA%B5%B4%ED%81%AC%EA%B8%B0&amp;rc=1" href="?w=tot&amp;m=&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81%20%EC%96%BC%EA%B5%B4%ED%81%AC%EA%B8%B0&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NSJ">박보영 얼굴크기</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;pg=1&amp;r=22&amp;p=1&amp;e1=%EB%B0%95%EB%B3%B4%EC%98%81%20%EB%AA%A9%EC%82%AC&amp;rc=1" href="?w=tot&amp;m=&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81%20%EB%AA%A9%EC%82%AC&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NSJ">박보영 목사</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;pg=1&amp;r=23&amp;p=1&amp;e1=%EB%B0%95%EB%B3%B4%EC%98%81%20%EC%95%88%ED%9A%A8%EC%84%AD&amp;rc=1" href="?w=tot&amp;m=&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81%20%EC%95%88%ED%9A%A8%EC%84%AD&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NSJ">박보영 안효섭</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;pg=1&amp;r=24&amp;p=1&amp;e1=%EB%B0%95%EB%B3%B4%EC%98%81%20%EB%8B%A8%EB%B0%9C&amp;rc=1" href="?w=tot&amp;m=&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81%20%EB%8B%A8%EB%B0%9C&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NSJ">박보영 단발</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;pg=1&amp;r=25&amp;p=1&amp;e1=%EC%9D%B4%EC%84%B1%EA%B2%BD&amp;rc=1" href="?w=tot&amp;m=&amp;q=%EC%9D%B4%EC%84%B1%EA%B2%BD&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NSJ">이성경</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;pg=1&amp;r=26&amp;p=1&amp;e1=%EB%B0%95%EB%B3%B4%EC%98%81%20%EC%A2%85%EB%B0%A9%EC%97%B0&amp;rc=1" href="?w=tot&amp;m=&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81%20%EC%A2%85%EB%B0%A9%EC%97%B0&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NSJ">박보영 종방연</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;pg=1&amp;r=27&amp;p=1&amp;e1=%EB%B0%95%EB%B3%B4%EC%98%81%20%EC%B2%AD%EB%B0%94%EC%A7%80&amp;rc=1" href="?w=tot&amp;m=&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81%20%EC%B2%AD%EB%B0%94%EC%A7%80&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NSJ">박보영 청바지</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;pg=1&amp;r=28&amp;p=1&amp;e1=%EB%B0%95%EB%B3%B4%EC%98%81%20%EC%84%B8%EB%A1%80%EB%AA%85&amp;rc=1" href="?w=tot&amp;m=&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81%20%EC%84%B8%EB%A1%80%EB%AA%85&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NSJ">박보영 세례명</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;pg=1&amp;r=29&amp;p=1&amp;e1=%EB%B0%95%EB%B3%B4%EC%98%81%20%EC%95%84%EB%B2%84%EC%A7%80&amp;rc=1" href="?w=tot&amp;m=&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81%20%EC%95%84%EB%B2%84%EC%A7%80&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NSJ">박보영 아버지</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;pg=1&amp;r=30&amp;p=1&amp;e1=%EB%93%9C%EB%9D%BC%EB%A7%88&amp;rc=1" href="?w=tot&amp;m=&amp;q=%EB%93%9C%EB%9D%BC%EB%A7%88&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=NSJ">드라마</a></span>
# </div>
# <a class="expender hide" data-log="dc=NSJ&amp;s=TO&amp;a=SJTO&amp;at=func" href="javascript:;" id="netizen_more_btn_top"> <span class="ico_rwd">더보기</span>
# </a>
# </div>
# </div>
# <div class="g_comp" disp-attr="PRF" style="position: relative;">
# <div class="wid_r" id="profColl"> <div class="coll_tit"> <h2 class="tit">인물</h2> <div class="mg_expander"> <a class="f_nb" href="http://myprofile.daum.net/top/" onclick="smartLog(this,'s=TO&amp;a=PXTO&amp;e=1&amp;d=34191&amp;dc=PRF',event);" target="_blank">마이프로필 관리</a> </div> </div> <div class="coll_cont"> <div class="rwd_info type_longtit3"> <div class="wrap_thumb" id="profMainThumb_img_0"> <a class="thumb" href="?q=%EB%B0%95%EB%B3%B4%EC%98%81&amp;w=img&amp;FaceType=y" onclick="smartLog(this,'s=TO&amp;a=PXTO&amp;pg=1&amp;r=1&amp;p=1&amp;rc=1&amp;d=34191&amp;e1=34191&amp;dc=PRF',event);"> <img alt="박보영" class="thumb_img" height="200" onerror="SF._jsImgErr('profMainThumb', '0', {q: '박보영', x: 160, y: 200, sv: 'QAS', ex: 'all', opt:'Y'});" src="https://search1.daumcdn.net/thumb/C160x200/?fname=http%3A%2F%2Fcfile67.uf.daum.net%2Fimage%2F2723993A55CC1A2117081A" width="160"/> </a> </div> <div class="wrap_cont type_thumb_s160"> <div class="info_tit"> <a class="tit_main" href="http://100.daum.net/encyclopedia/view/33/34191" onclick="smartLog(this,'s=TO&amp;a=PXTO&amp;pg=1&amp;r=1&amp;p=2&amp;rc=1&amp;d=34191&amp;e1=34191&amp;dc=PRF',event);" target="_blank"><b>박보영</b></a> <span class="tit_sub em_job">영화배우, 탤런트</span> </div> <dl class="dl_comm"> <dt class="tit_base">출생</dt> <dd class="cont"> <span class="em_birthday">1990년 2월 12일</span> (<span class="em_age">만 29세</span>)<span>, </span><span class="em_birth_city">충북 증평군</span> </dd> </dl> <dl class="dl_comm"> <dt class="tit_base">신체</dt> <dd class="cont"> <span class="em_height">158cm</span><span>, </span><span class="em_weight">41kg</span> </dd> </dl> <dl class="dl_comm"> <dt class="tit_base">소속사</dt> <dd class="cont"> <span class="em_belong_company"><a href="?DA=PRF&amp;w=tot&amp;q=%ED%94%BC%EB%8D%B0%EC%8A%A4%EC%8A%A4%ED%8C%8C%ED%8B%B0%EC%9C%B0" onclick="smartLog(this,'s=TO&amp;a=PXTO&amp;pg=1&amp;r=1&amp;p=8&amp;rc=1&amp;d=34191&amp;e1=34191&amp;dc=PRF',event);">피데스스파티윰</a></span> </dd> </dl> <dl class="dl_comm type_layer"> <dt class="tit_base">학력</dt> <dd class="cont"> <span class="em_school"><a href="?DA=PRF&amp;w=tot&amp;q=%EB%8B%A8%EA%B5%AD%EB%8C%80%ED%95%99%EA%B5%90" onclick="smartLog(this,'s=TO&amp;a=PXTO&amp;pg=1&amp;r=1&amp;p=12&amp;rc=1&amp;d=34191&amp;e1=34191&amp;dc=PRF',event);">단국대학교</a> 연극영화과 졸업</span>  <a class="more_comm" href="http://100.daum.net/encyclopedia/view/33/34191/profile" onclick="smartLog(this,'s=TO&amp;a=PXTO&amp;pg=1&amp;r=1&amp;p=13&amp;rc=1&amp;d=34191&amp;e1=34191&amp;dc=PRF',event);" target="_blank">외 3건</a> </dd> </dl> <dl class="dl_comm"> <dt class="tit_base">데뷔</dt> <dd class="cont"><span class="em_debut">2006년 EBS 드라마 '비밀의 교정'</span></dd> </dl> <dl class="dl_comm"> <dt class="tit_base">수상</dt> <dd class="cont"><span class="em_prizes">2018 제23회 소비자의 날 KCA 문화연예 시상식 2018 관객이 뽑은 올해의 배우</span>  <a class="more_comm" href="http://100.daum.net/encyclopedia/view/33/34191/profile" onclick="smartLog(this,'s=TO&amp;a=PXTO&amp;pg=1&amp;r=1&amp;p=14&amp;rc=1&amp;d=34191&amp;e1=34191&amp;dc=PRF',event);" target="_blank">외 29건</a></dd> </dl> <dl class="dl_comm"> <dt class="tit_base">사이트</dt> <dd class="cont"><span class="em_site"><a href="http://cafe.daum.net/parkboyoungfd" onclick="smartLog(this,'s=TO&amp;a=PXTO&amp;pg=1&amp;r=1&amp;p=16&amp;rc=1&amp;d=34191&amp;e1=34191&amp;dc=PRF',event);" target="_blank">팬카페</a></span></dd> </dl> <div class="refer_guide"> <span class="view_layer"> <span class="txt_refer">관계자 정보확인 (2015.8.13)</span> <button class="btn_help" onclick="smartLog(this,'s=TO&amp;a=PXTO&amp;e=2&amp;d=34191&amp;dc=PRF&amp;at=func',event);" type="button"><span class="ico_rwd ico_help">도움말</span></button> <span class="layer_detail"> <span class="txt_refer">Daum 인물 서비스에서는 본인(가족) 및 소속사로부터<br/>제공받은 정보와 웹상의 공개된 정보를 활용하여<br/>서비스를 제공하고 있습니다.<br/>본인(가족) 및 소속사로부터 확인된 인물정보에 대해서는<br/>자료제공출처 및 확인일자를 표시하고 있습니다.</span> <button class="btn_layer" onclick="smartLog(this,'s=TO&amp;a=PXTO&amp;e=3&amp;d=34191&amp;dc=PRF&amp;at=func',event);" type="button"> <span class= ...
# </div>
# <div class="line"></div><hr/>
# <div class="g_comp" disp-attr="NNS" style="position: relative;">
# ...
# </div>
# <div class="g_comp_s" disp-attr="EOA">
# <div class="content_realtime" id="ratNewsColl"> <div class="coll_tit"> <h2 class="tit">실시간 뉴스 검색어</h2> <div class="mg_expander"><span class="f_nb">5.3. 22:12</span></div> </div> <div class="coll_cont" id="ratNewsCollDetail"> <div class="tab_comp tab_box"> <ul class="list_tab tab_size3" id="rtissue_categories"> <li class="on"><a class="tab_tit" href="javascript:;" onclick="C.ratNewsColl.switchTab(0, 'EOA', event)"><span class="inner_tit">종합</span></a></li> <li><a class="tab_tit" href="javascript:;" onclick="C.ratNewsColl.switchTab(1, 'MBK', event)"><span class="inner_tit">연예</span></a></li> <li><a class="tab_tit" href="javascript:;" onclick="C.ratNewsColl.switchTab(2, 'DRU', event)"><span class="inner_tit">스포츠</span></a></li> </ul> </div> <div class="wrap_rank"> <ol class="list_rank"> <li> <div class="inner_item"> <span class="num_rank">1</span> <span class="keyword_rank"><a class="link_txt" href="?w=tot&amp;f=news&amp;rtmaxcoll=EOA&amp;DA=EOA&amp;q=%EA%B9%80%EB%AC%B4%EC%84%B1" onclick="smartLog(this,'dc=EOA&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=1',event);">김무성</a></span> </div> </li> <li> <div class="inner_item"> <span class="num_rank">2</span> <span class="keyword_rank"><a class="link_txt" href="?w=tot&amp;f=news&amp;rtmaxcoll=EOA&amp;DA=EOA&amp;q=%EC%82%AC%EB%9E%91%EC%9D%98%20%EA%B5%90%ED%9A%8C" onclick="smartLog(this,'dc=EOA&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=2',event);">사랑의 교회</a></span> </div> </li> <li> <div class="inner_item"> <span class="num_rank">3</span> <span class="keyword_rank"><a class="link_txt" href="?w=tot&amp;f=news&amp;rtmaxcoll=EOA&amp;DA=EOA&amp;q=%EB%82%98%EA%B2%BD%EC%9B%90%20%EC%82%AD%EB%B0%9C%20%EC%B2%AD%EC%9B%90" onclick="smartLog(this,'dc=EOA&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=3',event);">나경원 삭발 청원</a></span> </div> </li> <li> <div class="inner_item"> <span class="num_rank">4</span> <span class="keyword_rank"><a class="link_txt" href="?w=tot&amp;f=news&amp;rtmaxcoll=EOA&amp;DA=EOA&amp;q=%ED%99%98%EA%B2%BD%EB%B6%80%EC%9E%A5%EA%B4%80%20%EC%97%AC%EC%88%98%EB%B0%A9%EB%AC%B8" onclick="smartLog(this,'dc=EOA&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=4',event);">환경부장관 여수방문</a></span> </div> </li> <li> <div class="inner_item"> <span class="num_rank">5</span> <span class="keyword_rank"><a class="link_txt" href="?w=tot&amp;f=news&amp;rtmaxcoll=EOA&amp;DA=EOA&amp;q=%EC%8A%A4%ED%83%80%EA%B0%95%EC%82%AC" onclick="smartLog(this,'dc=EOA&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=5',event);">스타강사</a></span> </div> </li> </ol> <ol class="list_rank"> <li> <div class="inner_item"> <span class="num_rank">6</span> <span class="keyword_rank"><a class="link_txt" href="?w=tot&amp;f=news&amp;rtmaxcoll=EOA&amp;DA=EOA&amp;q=%ED%81%AC%EB%82%99%EC%83%88" onclick="smartLog(this,'dc=EOA&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=6',event);">크낙새</a></span> </div> </li> <li> <div class="inner_item"> <span class="num_rank">7</span> <span class="keyword_rank"><a class="link_txt" href="?w=tot&amp;f=news&amp;rtmaxcoll=EOA&amp;DA=EOA&amp;q=%EC%96%B4%EB%A6%B0%EC%9D%B4%EB%82%A0%20%ED%96%89%EC%82%AC" onclick="smartLog(this,'dc=EOA&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=7',event);">어린이날 행사</a></span> </div> </li> <li> <div class="inner_item"> <span class="num_rank">8</span> <span class="keyword_rank"><a class="link_txt" href="?w=tot&amp;f=news&amp;rtmaxcoll=EOA&amp;DA=EOA&amp;q=%EB%A1%AF%EB%8D%B0%ED%83%80%EC%9B%8C%20%EB%B6%88%EA%BD%83%EC%B6%95%EC%A0%9C" onclick="smartLog(this,'dc=EOA&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=8',event);">롯데타워 불꽃축제</a></span> </div> </li> <li> <div class="inner_item"> <span class="num_rank">9</span> <span class="keyword_rank"><a class="link_txt" href="?w=tot&amp;f=news&amp;rtmaxcoll=EOA&amp;DA=EOA&amp;q=%EB%B0%95%EC%83%81%EA%B8%B0" onclick="smartLog(this,'dc=EOA&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=9',event);">박상기</a></span> </div> </li> <li> <div class="inner_item"> <span class="num_rank">10</span> <span class="keyword_rank"><a class="link_txt" href="?w=tot&am ...
# </div>
# <div class="g_comp_s" disp-attr="RSJ">
# <div class="content_keyword" id="netizenColl_right">
# <div class="coll_tit">
# <h2 class="tit">관련검색어</h2>
# </div>
# <div class="coll_cont mg_cont">
# <ul class="list_keyword">
# <li><a class="link_txt" data-log="dc=RSJ&amp;s=TO&amp;a=SDTO&amp;r=1&amp;p=1&amp;e1=%EB%B0%95%EB%B3%B4%EC%98%81%20%EB%AA%B8%EB%A7%A4" href="?w=tot&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81%20%EB%AA%B8%EB%A7%A4&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=RSJ"><span class="txt_keyword" data="박보영 몸매">박보영 몸매</span></a></li>
# <li><a class="link_txt" data-log="dc=RSJ&amp;s=TO&amp;a=SDTO&amp;r=2&amp;p=1&amp;e1=%EB%B0%95%EB%B3%B4%EC%98%81%20%EB%B9%84%ED%82%A4%EB%8B%88" href="?w=tot&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81%20%EB%B9%84%ED%82%A4%EB%8B%88&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=RSJ"><span class="txt_keyword" data="박보영 비키니">박보영 비키니</span></a></li>
# <li><a class="link_txt" data-log="dc=RSJ&amp;s=TO&amp;a=SDTO&amp;r=3&amp;p=1&amp;e1=%EB%B0%95%EB%B3%B4%EC%98%81%20%ED%82%A4" href="?w=tot&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81%20%ED%82%A4&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=RSJ"><span class="txt_keyword" data="박보영 키">박보영 키</span></a></li>
# <li><a class="link_txt" data-log="dc=RSJ&amp;s=TO&amp;a=SDTO&amp;r=4&amp;p=1&amp;e1=%EB%B0%95%EB%B3%B4%EC%98%81%20%EC%B6%9C%EC%97%B0%EB%A3%8C" href="?w=tot&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81%20%EC%B6%9C%EC%97%B0%EB%A3%8C&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=RSJ"><span class="txt_keyword" data="박보영 출연료">박보영 출연료</span></a></li>
# <li><a class="link_txt" data-log="dc=RSJ&amp;s=TO&amp;a=SDTO&amp;r=5&amp;p=1&amp;e1=%ED%95%9C%EC%A7%80%EB%AF%BC" href="?w=tot&amp;q=%ED%95%9C%EC%A7%80%EB%AF%BC&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=RSJ"><span class="txt_keyword" data="한지민">한지민</span></a></li>
# <li><a class="link_txt" data-log="dc=RSJ&amp;s=TO&amp;a=SDTO&amp;r=6&amp;p=1&amp;e1=%EC%95%88%ED%9A%A8%EC%84%AD" href="?w=tot&amp;q=%EC%95%88%ED%9A%A8%EC%84%AD&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=RSJ"><span class="txt_keyword" data="안효섭">안효섭</span></a></li>
# <li><a class="link_txt" data-log="dc=RSJ&amp;s=TO&amp;a=SDTO&amp;r=7&amp;p=1&amp;e1=%EC%9D%B4%EB%B3%B4%EC%98%81" href="?w=tot&amp;q=%EC%9D%B4%EB%B3%B4%EC%98%81&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=RSJ"><span class="txt_keyword" data="이보영">이보영</span></a></li>
# <li><a class="link_txt" data-log="dc=RSJ&amp;s=TO&amp;a=SDTO&amp;r=8&amp;p=1&amp;e1=%EB%B0%95%EB%B3%B4%EC%98%81%20%EC%96%B4%EB%B9%84%EC%8A%A4" href="?w=tot&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81%20%EC%96%B4%EB%B9%84%EC%8A%A4&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=RSJ"><span class="txt_keyword" data="박보영 어비스">박보영 어비스</span></a></li>
# <li><a class="link_txt" data-log="dc=RSJ&amp;s=TO&amp;a=SDTO&amp;r=9&amp;p=1&amp;e1=%EC%86%90%EC%98%88%EC%A7%84" href="?w=tot&amp;q=%EC%86%90%EC%98%88%EC%A7%84&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=RSJ"><span class="txt_keyword" data="손예진">손예진</span></a></li>
# <li><a class="link_txt" data-log="dc=RSJ&amp;s=TO&amp;a=SDTO&amp;r=10&amp;p=1&amp;e1=%EB%B0%95%EB%B3%B4%EC%98%81%20%EC%8B%A4%EB%AC%BC" href="?w=tot&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81%20%EC%8B%A4%EB%AC%BC&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=RSJ"><span class="txt_keyword" data="박보영 실물">박보영 실물</span></a></li>
# <li><a class="link_txt" data-log="dc=RSJ&amp;s=TO&amp;a=SDTO&amp;r=11&amp;p=1&amp;e1=%EA%B9%80%EC%98%81%EA%B4%91" href="?w=tot&amp;q=%EA%B9%80%EC%98%81%EA%B4%91&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=RSJ"><span class="txt_keyword" data="김영광">김영광</span></a></li>
# <li><a class="link_txt" data-log="dc=RSJ&amp;s=TO&amp;a=SDTO&amp;r=12&amp;p=1&amp;e1=%EA%B9%80%EC%A7%80%EC%9B%90" href="?w=tot&amp;q=%EA%B9%80%EC%A7%80%EC%9B%90&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=RSJ"><span class="txt_keyword" data="김지원">김지원</span></a></li>
# <li><a class="link_txt" data-log="dc=RSJ&amp;s=TO&amp;a=SDTO&amp;r=13&amp;p=1&amp;e1=%EB%B0%95%EB%AF%BC%EC%98%81" href="?w=tot&amp;q=%EB%B0%95%EB%AF%BC%EC%98%81&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=RSJ"><span class="txt_keyword" data="박민영">박민영</span></a></li>
# <li><a class="link_txt" data-log="dc=RSJ&amp;s=TO&amp;a=SDTO&amp;r=14&amp;p=1&amp;e1=%EB%B0%95%ED%98%95%EC%8B%9D" href="?w=tot&amp;q=%EB%B0%95%ED%98%95%EC%8B%9D&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=RSJ"><span class="txt_keyword" data="박형식">박형식</span></a></li>
# <li><a class="link_txt" data-log="dc=RSJ&amp;s=TO&amp;a=SDTO&amp;r=15&amp;p=1&amp;e1=%EB%B0%95%EB%B3%B4%EC%98%81%20%EB%8C%80%EB%B2%95%EA%B4%80" href="?w=tot&amp;q=%EB%B0%95%EB%B3%B4%EC%98%81%20%EB%8C%80%EB%B2%95%EA%B4%80&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=RSJ"><span class="txt_keyword" data="박보영 대법관">박보영 대법관</span></a></li>
# <li><a class="link_txt" data-log="dc=RSJ&amp;s=TO&amp;a=SDTO&amp;r=16&amp;p=1&amp;e1=%EC%9E%A5%EB%82%98%EB%9D%BC" href="?w=tot&amp;q=%EC%9E%A5%EB%82%98%EB%9D%BC&amp;nzq=%EB%B0%95%EB%B3%B4%EC%98%81&amp;DA=RSJ"><span class="txt_keyword" data="장나라">장나라</span></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div style="display:block;overflow:hidden;height:0;clear:both;font-size:0;line-height:0;visibility:hidden;">\00f0</div>
# </aside>
# </div>
# <a class="aside_quick" href="javascript:;">맨위로<span class="ico_rwd"></span></a>
# </article>
# <footer id="daumFoot">
# <div class="inner_footer" id="innerFooter">
# <div id="suggestFooter">
# <form class="d_sch" id="daumSearchFoot" method="get" name="search1" onsubmit="check_submit(event); return false;">
# <fieldset class="fld_total">
# <legend class="screen_out">검색폼</legend>
# <input name="nil_ch" type="hidden" value=""/>
# <input name="rtupcoll" type="hidden" value=""/>
# <input name="nil_suggest" type="hidden" value="btn"/>
# <input name="DA" type="hidden" value="MEK"/>
# <input name="w" type="hidden" value="tot"/>
# <input name="sq" type="hidden" value=""/>
# <input name="o" type="hidden" value=""/>
# <input name="sugo" type="hidden" value=""/>
# <input name="m" type="hidden" value=""/>
# <div class="box_searchbar">
# <div class="inner_searchbar">
# <input autocomplete="off" class="tf_keyword" id="q1" name="q" onclick="cleanKwd(this);" title="검색어 입력" type="text" value="박보영"/>
# <button class="ico_ksearch btn_ksearch" id="daumBtnSearch2" type="submit"><span class="ir_wa">검색</span></button>
# </div>
# </div>
# </fieldset>
# </form>
# <div class="wrap_suggestBox"><div class="suggestBox box_sub reverseType" id="suggestBox2"></div></div>
# </div>
# <script type="text/javascript">
# (function(){
# var footerSearchInp = jQuery("#q1"), boxSearchBar = jQuery("#daumFoot .box_searchbar");
# footerSearchInp.on("focus", function() {
# boxSearchBar.addClass("search_on");
# });
# footerSearchInp.on("blur", function() {
# boxSearchBar.removeClass("search_on");
# });
# var footerSuggestInstance = new suggest.Suggest(document.getElementById('suggestFooter'), {
# inputEl: 'q1',
# suggestBoxEl: 'suggestBox2',
# searchButtonEl: 'daumBtnSearch2',
# type: 'DEFAULT',
# autoFocus: 'NORMAL',
# isReverse: true,
# suggestLimit: 15,
# enableFooter: true
# });
# footerSuggestInstance.on('click-item', function (event) {
# var f = document.search1;
# var clickedItemInfo = footerSuggestInstance.getActiveItem();
# var data = clickedItemInfo.data;
# var index = clickedItemInfo.index;
# var type = clickedItemInfo.type;
# var sgtq = null;
# var sn = null;
# f.DA.value = "";
# f.nil_suggest.value = "";
# if (data) {
# sgtq = footerSuggestInstance.getUserEnteredQuery();
# sn = index + 1;
# if (sgtq != null && sgtq != "" ) {
# if (sgtq != null && sgtq != "" && sn != null && sn != "") {
# f.sq.value = sgtq;
# f.o.value = sn;
# f.sugo.value = footerSuggestInstance.getSuggestions().length;
# }
# }
# f.DA.value = "FKB";
# f.nil_suggest.value = "sugsch";
# } else {
# f.nil_suggest.value = "btn";
# f.DA.value = "MEK";
# }
# check_submit(event, document.search1);
# });
# })();
# </script>
# <div class="footer_comm">
# <a class="link_info" href="http://daumsearch.tistory.com" onclick="smartLog(this, 'pg=1&amp;p=10&amp;dc=CCC&amp;r=1', event);" target="_blank">검색블로그</a><span class="txt_bar">|</span>
# <a class="link_info" href="https://register.search.daum.net/" onclick="smartLog(this, 'pg=1&amp;p=9&amp;dc=CCC&amp;r=1', event);" target="_blank">사이트ㆍ지역 등록신청</a><span class="txt_bar">|</span>
# <a class="link_info" href="http://partner.search.daum.net/partner/index.daum" onclick="smartLog(this, 'pg=1&amp;p=12&amp;dc=CCC&amp;r=1', event);" target="_blank">검색제휴</a><span class="txt_bar">|</span>
# <a class="link_info" href="https://business.kakao.com/info/keywordad" onclick="smartLog(this, 'pg=1&amp;p=2&amp;dc=CCC&amp;r=1', event);" target="_blank">키워드광고</a><span class="txt_bar">|</span>
# <a class="link_info" href="http://local.biz.daum.net/" onclick="smartLog(this, 'pg=1&amp;p=3&amp;dc=CCC&amp;r=1', event);" target="_blank">로컬광고</a><span class="txt_bar">|</span>
# <a class="link_info" href="https://with.kakao.com/crossmedia" onclick="smartLog(this, 'pg=1&amp;p=8&amp;dc=CCC&amp;r=1', event);" target="_blank">크로스미디어</a><span class="txt_bar">|</span>
# <a class="link_info" href="http://cs.daum.net/faq/15.html" onclick="smartLog(this, 'pg=1&amp;p=6&amp;dc=CCC&amp;r=1', event);" target="_blank">고객센터</a>
# <span class="txt_bar">|</span>
# <a class="link_info" href="javascript:;" onclick="SF._jsHarmfulReport();smartLog(this, 'pg=1&amp;p=13&amp;dc=CCC&amp;r=1&amp;at=func', event);">유해정보신고</a>
# <address class="copyright">   ⓒ <a class="link_daum" href="http://kakaocorp.com" onclick="smartLog(this, 'pg=1&amp;p=11&amp;dc=CCC&amp;r=1', event);" target="_blank">Kakao Corp.</a></address>
# </div>
# </div>
# </footer>
# </article>
# <script type="text/javascript">
# var __MiniDaumObj = null;
# var minidaum_options = null;
# (function() {
# minidaum_options = {
# bgType: "",
# enableLogoutRetun: true,
# disableHotissue: true,
# disableLogo: true,
# disableTracker: true,
# enableShield: false
# };
# })();
# </script>
# <script async="" charset="utf-8" defer="" src="//go.daum.net/jsa_minidaum_pc.daum" type="text/javascript"></script>
# <script type="text/javascript">
# SF.CommonModule && SF.CommonModule.init && SF.CommonModule.init();
# </script>
# <script charset="utf-8" src="//t1.daumcdn.net/tiara/js/td.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# window.__pageTracker = {};
# if (typeof __Tiara !== 'undefined' && typeof __Tiara.__getTracker !== 'undefined') {
# __pageTracker = __Tiara.__getTracker();
# } else {
# __pageTracker.__trackPageview = function() {};
# __pageTracker.__addParam = function() {};
# }
# var svcdomain = window.viewio === 'i' ? window.param_w + '.search.daum.net' : 'nate.search.daum.net';
# __pageTracker.__addParam("svcdomain",svcdomain);
# __pageTracker.__addParam('param1',mk);
# window.setTimeout(function() { try { window.__pageTracker.__trackPageview(); } catch(e) {} }, 1);
# </script>
# <script type="text/javascript">
# window.roosevelt_params_queue = window.roosevelt_params_queue || [];
# window.roosevelt_params_queue.push({
# channel_id: "dk", channel_label: "search", keyword: window.topQuery
# });
# </script>
# <script async="" src="//t1.daumcdn.net/midas/rt/dk_se/roosevelt_dk_se.js" type="text/javascript"></script>
# <!-- SA 삭제 -->
# <!-- end SA 삭제 -->
# </body>
# </html>

# %%
for _ in daum.find_all("div",{"class":"wrap_tit"}):
    a = _.find("a")
    if a:
        print(a.text.strip())
        print(a["href"])
# Out:
# "세젤흔녀로 변신한 박보영"..유제원 감독X박보영 '어비스' (종합)
# http://v.media.daum.net/v/20190503153440722?f=o
# '어비스' 이성재 "다시 태어난다면? 예쁜 박보영으로"..박보영 '폭소'
# http://v.media.daum.net/v/20190503145429254?f=o
# 박보영이 가장 흔한 여자, 설득력 있을까 '어비스'
# http://v.media.daum.net/v/20190503172414326?f=o
# [현장]'어비스' 박보영 "김사랑과 차이? 커졌다 작아졌다.."
# http://v.media.daum.net/v/20190503165134297?f=o
# 김영광 박보영 열애 터진 이유
# http://adam24eve.tistory.com/858
# 박보영 실제 키는 도대체 몇일까?
# http://papa0717.tistory.com/223
# 박보영 나이 키 몸매 대박
# http://k3k2y.tistory.com/35
# 박보영 키 나이 인스타그램 드라마 어비스
# http://listup.tistory.com/248
# 드라마 어비스 인물 소개, 예고편(박보영, 안효섭 주연)
# http://cafe.daum.net/subdued20club/ReHf/2282606?q=%EB%B0%95%EB%B3%B4%EC%98%81
# 박보영과 역대급 케미뽐낸 상대배우 고르기
# http://cafe.daum.net/subdued20club/ReHf/2280152?q=%EB%B0%95%EB%B3%B4%EC%98%81
# 런닝맨 나올 때마다 케미 보여준 송지효X박보영.jpgif
# http://cafe.daum.net/ok1221/9Zdf/1524913?q=%EB%B0%95%EB%B3%B4%EC%98%81
# 박보영이 왜 못 오를 나무냐는 박수홍.jpg
# http://cafe.daum.net/ASMONACOFC/gAVU/1243818?q=%EB%B0%95%EB%B3%B4%EC%98%81
# 박보영
# https://ko.wikipedia.org/wiki/%EB%B0%95%EB%B3%B4%EC%98%81
# 박보영 (법조인)
# https://ko.wikipedia.org/wiki/%EB%B0%95%EB%B3%B4%EC%98%81%20%28%EB%B2%95%EC%A1%B0%EC%9D%B8%29
# 박보영 갤러리
# http://gall.dcinside.com/board/lists/?id=parkboyoung
# 박보영 공식팬카페 뽀르테
# http://cafe.daum.net/parkboyoungfd
# Park Bo Young V LIVE
# http://channels.vlive.tv/FCE49/video
# 인천방주교회
# http://www.bjc.or.kr/
# 박보영, 송지효는 ‘친언니’ 이광수는 ‘그냥 기린’
# javascript:;
# 박형식, 박보영을 번쩍(!) 둘만의 '피아노 키스♥' //ㅁ//
# javascript:;
# '비밀의 교정'때의 박보영☆
# javascript:;
# [메이킹]세젤흔녀로 돌아온 박보영, ＜어비스 : 영혼소생구슬＞ 대본리딩 현장 최초 공개!
# javascript:;
# 애교 있어 보이지만 상여자(?) 스타일이라는 박보영
# javascript:;
# 박보영누나 과속스캔들찍고 또 다른 드라마나 영화 찍나요?> 박보영누나...
# http://tip.daum.net/answer/55072609?q=%EB%B0%95%EB%B3%B4%EC%98%81
# 박보영, 과속스캔들 OST 중 '아마도그건' 불렀다던데, 이번에 과속...
# http://tip.daum.net/answer/54767339?q=%EB%B0%95%EB%B3%B4%EC%98%81
# 박보영 질문요. 박보영 진짜 예쁘더군요... 박보영이 대체 누군...
# http://tip.daum.net/answer/54866982?q=%EB%B0%95%EB%B3%B4%EC%98%81
# 박보영, 제2의 문근영이라는 호칭때문에 악플에 시달렸나요? 아역배우...
# http://tip.daum.net/answer/54503481?q=%EB%B0%95%EB%B3%B4%EC%98%81
