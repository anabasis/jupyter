# %%
from urllib import request

# %%
resp = request.urlopen("http://www.google.com")

# %%
resp.geturl()
# Out:
# 'http://www.google.com'

# %%
resp.reason
resp.getcode()
print(resp.info())
# Out:
# Date: Tue, 30 Apr 2019 11:35:55 GMT
# Expires: -1
# Cache-Control: private, max-age=0
# Content-Type: text/html; charset=ISO-8859-1
# P3P: CP="This is not a P3P policy! See g.co/p3phelp for more info."
# Server: gws
# X-XSS-Protection: 0
# X-Frame-Options: SAMEORIGIN
# Set-Cookie: 1P_JAR=2019-04-30-11; expires=Thu, 30-May-2019 11:35:55 GMT; path=/; domain=.google.com
# Set-Cookie: NID=182=D7Z011ydqJFCbIDQbgR_qVTAKp3_oGx0f4LT7vXxKh6ZXiyoUXm2GymUQnr0aQ86cH2WudcL1QDUYec34B-v7IRDxyHEV8r7ulcR7PEGm9gtSeb2SdlevAmJIqoi75XnOryj0wvAEirLbylr_LbAUelmG5OmJV2kAr8SIh_N1gg; expires=Wed, 30-Oct-2019 11:35:55 GMT; path=/; domain=.google.com; HttpOnly
# Accept-Ranges: none
# Vary: Accept-Encoding
# Connection: close

# %%
resp.getheaders()
# Out:
# [('Date', 'Tue, 30 Apr 2019 11:35:55 GMT'),
#  ('Expires', '-1'),
#  ('Cache-Control', 'private, max-age=0'),
#  ('Content-Type', 'text/html; charset=ISO-8859-1'),
#  ('P3P', 'CP="This is not a P3P policy! See g.co/p3phelp for more info."'),
#  ('Server', 'gws'),
#  ('X-XSS-Protection', '0'),
#  ('X-Frame-Options', 'SAMEORIGIN'),
#  ('Set-Cookie',
#   '1P_JAR=2019-04-30-11; expires=Thu, 30-May-2019 11:35:55 GMT; path=/; domain=.google.com'),
#  ('Set-Cookie',
#   'NID=182=D7Z011ydqJFCbIDQbgR_qVTAKp3_oGx0f4LT7vXxKh6ZXiyoUXm2GymUQnr0aQ86cH2WudcL1QDUYec34B-v7IRDxyHEV8r7ulcR7PEGm9gtSeb2SdlevAmJIqoi75XnOryj0wvAEirLbylr_LbAUelmG5OmJV2kAr8SIh_N1gg; expires=Wed, 30-Oct-2019 11:35:55 GMT; path=/; domain=.google.com; HttpOnly'),
#  ('Accept-Ranges', 'none'),
#  ('Vary', 'Accept-Encoding'),
#  ('Connection', 'close')]

# %%
# https://www.google.com/search?q=%EB%B0%95%EB%B3%B4%EC%98%81&rlz=1C1CHBD_koKR847KR847&oq=%EB%B0%95%EB%B3%B4%EC%98%81&aqs=chrome..69i57j0l5.3532j0j8&sourceid=chrome&ie=UTF-8

resp = request.urlopen("https://www.google.com/search?q=%EB%B0%95%EB%B3%B4%EC%98%81&rlz=1C1CHBD_koKR847KR847&oq=%EB%B0%95%EB%B3%B4%EC%98%81&aqs=chrome..69i57j0l5.3532j0j8&sourceid=chrome&ie=UTF-8")
resp.geturl()
resp.reason
resp.getcode()
print(resp.info())
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-9-cb5409d44eb1> in <module>
#       1 # https://www.google.com/search?q=%EB%B0%95%EB%B3%B4%EC%98%81&rlz=1C1CHBD_koKR847KR847&oq=%EB%B0%95%EB%B3%B4%EC%98%81&aqs=chrome..69i57j0l5.3532j0j8&sourceid=chrome&ie=UTF-8
#       2
# ----> 3 resp = request.urlopen("https://www.google.com/search?q=%EB%B0%95%EB%B3%B4%EC%98%81&rlz=1C1CHBD_koKR847KR847&oq=%EB%B0%95%EB%B3%B4%EC%98%81&aqs=chrome..69i57j0l5.3532j0j8&sourceid=chrome&ie=UTF-8")
#       4 resp.geturl()
#       5 resp.reason
#
# D:\EDU\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# D:\EDU\lib\urllib\request.py in open(self, fullurl, data, timeout)
# ...

# %%
from urllib import request, error
 
try :
    resp = request.urlopen("https://www.google.com/search?q=%EB%B0%95%EB%B3%B4%EC%98%81&rlz=1C1CHBD_koKR847KR847&oq=%EB%B0%95%EB%B3%B4%EC%98%81&aqs=chrome..69i57j0l5.3532j0j8&sourceid=chrome&ie=UTF-8")
except error.HTTPError as e :
    print(e.code)
    print(e.reason)
    print(e.headers)
# Out:
# 403
# Forbidden
# Content-Type: text/html; charset=UTF-8
# Date: Tue, 30 Apr 2019 11:46:22 GMT
# Server: gws
# Cache-Control: private
# X-XSS-Protection: 0
# X-Frame-Options: SAMEORIGIN
# Alt-Svc: quic=":443"; ma=2592000; v="46,44,43,39"
# Accept-Ranges: none
# Vary: Accept-Encoding
# Connection: close

# %%
from urllib import request, error

url = "https://www.google.com/search?q=%EB%B0%95%EB%B3%B4%EC%98%81&rlz=1C1CHBD_koKR847KR847&oq=%EB%B0%95%EB%B3%B4%EC%98%81&aqs=chrome..69i57j0l5.3532j0j8&sourceid=chrome&ie=UTF-8"
req = request.Request(url, 
               headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; WOW64; Trident/7.0; rv:11.0) like Gecko"},
               method="GET"
               )

try :
    resp = request.urlopen(req)
except error.HTTPError as e :
    print(e.code)
    print(e.reason)
    print(e.headers)
resp.geturl()
resp.getcode()
resp.getheaders()
# Out:
# [('Content-Type', 'text/html; charset=UTF-8'),
#  ('Date', 'Tue, 30 Apr 2019 11:57:36 GMT'),
#  ('Expires', '-1'),
#  ('Cache-Control', 'private, max-age=0'),
#  ('P3P', 'CP="This is not a P3P policy! See g.co/p3phelp for more info."'),
#  ('Server', 'gws'),
#  ('X-XSS-Protection', '0'),
#  ('X-Frame-Options', 'SAMEORIGIN'),
#  ('Set-Cookie',
#   '1P_JAR=2019-04-30-11; expires=Thu, 30-May-2019 11:57:36 GMT; path=/; domain=.google.com'),
#  ('Set-Cookie',
#   'CGIC=EhQxQzFDSEJEX2tvS1I4NDdLUjg0Nw; expires=Sun, 27-Oct-2019 11:57:36 GMT; path=/complete/search; domain=.google.com; HttpOnly'),
#  ('Set-Cookie',
#   'CGIC=EhQxQzFDSEJEX2tvS1I4NDdLUjg0Nw; expires=Sun, 27-Oct-2019 11:57:36 GMT; path=/search; domain=.google.com; HttpOnly'),
#  ('Set-Cookie',
# ...

# %%
from urllib import request, error

url = "https://www.google.com/search?q=박보영"
req = request.Request(url, 
               headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; WOW64; Trident/7.0; rv:11.0) like Gecko"},
               method="GET"
               )

try :
    resp = request.urlopen(req)
except error.HTTPError as e :
    print(e.code)
    print(e.reason)
    print(e.headers)
resp.geturl()
resp.getcode()
resp.getheaders()
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-1-44fff04ffd74> in <module>
#       8
#       9 try :
# ---> 10     resp = request.urlopen(req)
#      11 except error.HTTPError as e :
#      12     print(e.code)
#
# D:\EDU\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# D:\EDU\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# D:\EDU\lib\urllib\request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# ...

# %%
from urllib import parse

parse.urlencode({"q":"박보영"})
# Out:
# 'q=%EB%B0%95%EB%B3%B4%EC%98%81'

# %%
from urllib import request, parse, error
# 200 => OK
# 400 => My Fault
# 500 => You Fault => Traffic 과도하게 증가
header={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; WOW64; Trident/7.0; rv:11.0) like Gecko"}

def download(url, params ={}, retries = 3) :
    resp = None
    try :
        req = request.Request(url + "?" + parse.urlencode(params), headers=header)
        resp = request.urlopen(req)
    except error.HTTPError as e :
        if 500 <= e.code < 600 and retries > 0:
            resp = download(url, params, retries - 1)
        else :
            print(e.code)
            print(e.reason)
            print(e.geturl())
            print(e.headers)
    
    return resp

# %%
params = {"q":"박보영","a":"한글"}
resp = download("https://www.google.com/search", params)

# %%
resp.read().decode("utf-8")
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="ko"><head><meta content="IE=edge" http-equiv="X-UA-Compatible"><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>박보영 - Google 검색</title><script nonce="HVLrC806SN1Ux6q0YG9HZw==">(function(){window.google={kEI:\'D0PIXOaVLsTHrQHVy4TABg\',kEXPI:\'31\',authuser:0,kscs:\'c9c918f0_D0PIXOaVLsTHrQHVy4TABg\',kGL:\'KR\'};google.sn=\'web\';google.kHL=\'ko\';})();(function(){google.lc=[];google.li=0;google.getEI=function(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||google.kEI};google.getLEI=function(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b};google.https=function(){return"https:"==window.location.protocol};google.ml=function(){return null};google.time=function(){return(new Date).getTime()};google.log=f
# ...

# %%
result = parse.urlparse("https://www.google.com/search?q=%EB%B0%95%EB%B3%B4%EC%98%81")
[_ for _ in result]
# Out:
# ['https', 'www.google.com', '/search', '', 'q=%EB%B0%95%EB%B3%B4%EC%98%81', '']

# %%
parse.urljoin("https://www.google.com/search?q=%EB%B0%95%EB%B3%B4%EC%98%81","/search/about")
# Out:
# 'https://www.google.com/search/about'

# %%
parse.unquote("%EB%B0%95%EB%B3%B4%EC%98%81")
# Out:
# '박보영'

# %%
parse.quote("박 보 영"), parse.quote_plus("박 보 영")
# Out:
# ('%EB%B0%95%20%EB%B3%B4%20%EC%98%81', '%EB%B0%95+%EB%B3%B4+%EC%98%81')
